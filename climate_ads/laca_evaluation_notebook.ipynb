# %% [markdown]
# ## Imports

# %%
import sqlite3
import glob
import time
import itertools 

import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.notebook import tqdm
# Out:
# /var/folders/m8/kq3tbvsx79n47wprd2zwv5hm0000gn/T/ipykernel_12181/1025221560.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# _____

# %% [markdown]
# ## 1. Data Ingestion
#
# Read the data from the database.

# %%
annotated_dbs = glob.glob(f'./dataset/laca_system/*.db')

print("Found the following dbs : " , annotated_dbs)

synchronous_annotators = ['group_1' , 'group_2'] 
asynchronous_annotators = ['async_1' , 'async_2' , 'async_3'] 
annotators = synchronous_annotators + asynchronous_annotators
annotator2df = {}

for db_path in  annotated_dbs : 

    con = sqlite3.connect(db_path)
    tweet_df = pd.read_sql_query('SELECT * FROM tweet;' , con) 
    theme_df = pd.read_sql_query('SELECT * FROM theme;' , con) 
    theme_df = theme_df.rename(columns={'id' : 'theme_id'})
    merged_df = tweet_df.merge(theme_df , how='left' , on='theme_id')

    for key in annotators : 
        if key in db_path : 
            annotator2df[key] = merged_df
# Out:
# Found the following dbs :  ['./dataset/laca_system/async_1.db', './dataset/laca_system/group_1.db', './dataset/laca_system/async_3.db', './dataset/laca_system/group_2.db', './dataset/laca_system/async_2.db']

# %% [markdown]
# ### 1.a. Random Sampling rows for manual annotations
#
# Pull 200 samples from both synchronous and asynchronous groups to manually review label quality. Pulling from top 25th percentile is done later.

# %%
synchronous_random_samples = []
asynchronous_random_samples = []

for annotator , df in annotator2df.items(): 
    if annotator in synchronous_annotators: 
        synchronous_random_samples.append(df.sample(n=100))
    if annotator in asynchronous_annotators: 
        asynchronous_random_samples.append(df.sample(n=67))

res_df = pd.concat(synchronous_random_samples)
async_df = pd.concat(asynchronous_random_samples)

res_df = res_df[['text' , 'name']].sample(frac=1)
async_df = async_df[['text' , 'name']].sample(frac=1)

# res_df.to_csv('./dataset/generated_samples/laca_sync_sample_all.csv' , index=False, sep='\t')
# async_df.to_csv('./dataset/generated_samples/laca_async_sample_all.csv' , index=False, sep='\t')

# %% [markdown]
# _____

# %% [markdown]
# ## 2. Jaccard Similarity
#
# Jaccard similarity for two themes is calculated by the union of their documents divided by the intersection of their documents.

# %%
results = []

for anno_1 , anno_2 in itertools.permutations(annotators , 2): 
    anno_1_themes = annotator2df[anno_1]['name'].unique()
    anno_2_themes = annotator2df[anno_2]['name'].unique()
    for anno_1_theme , anno_2_theme in itertools.product(anno_1_themes , anno_2_themes): 
        result = {'anno_1' : anno_1 , 
                  'anno_2' : anno_2 , 
                  'anno_1_theme' : anno_1_theme ,
                  'anno_2_theme' : anno_2_theme}
        anno_1_tweet_ids = set(annotator2df[anno_1][annotator2df[anno_1]['name']==anno_1_theme]['tweet_id'])
        anno_2_tweet_ids = set(annotator2df[anno_2][annotator2df[anno_2]['name']==anno_2_theme]['tweet_id'])
        intersection = anno_1_tweet_ids.intersection(anno_2_tweet_ids)
        union = anno_1_tweet_ids.union(anno_2_tweet_ids)
        jaccard_sim = len(intersection) / len(union)
        result['jaccard_sim'] = jaccard_sim
        results.append(result)

jaccard_df = pd.DataFrame(results)

# %% [markdown]
# ### 2.a. Getting max jaccard similarity for synchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(synchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(synchronous_annotators))]

for anno_1_theme in filtered_df['anno_1_theme'].unique(): 
    if ('kmeans' not in anno_1_theme.lower()) and ('Unknown' not in anno_1_theme.strip()) and (anno_1_theme != "None"):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('None')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('KMeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Synchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
print(res_df.count())
# Out:
# Synchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.09
# Standard Deviation of Jaccard Similarity: 0.07
# anno_1          43
# anno_2          43
# anno_1_theme    43
# anno_2_theme    43
# jaccard_sim     43
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                            anno_1_theme  \
# 0   group_1  group_2                                  GoBold
# 1   group_1  group_2          DemandClimateActionFromLeaders
# 2   group_1  group_2                  PublicLandExploitation
# 3   group_1  group_2                   BellbrookWokeRadicals
# 4   group_1  group_2                        ClimateEmergency
# 5   group_1  group_2                  GreenEnergyCreatesJobs
# 6   group_1  group_2                         RestoreVirginia
# 7   group_1  group_2                          AbandonedWells
# 8   group_1  group_2            AntiFossilFuelInfrastructure
# 9   group_1  group_2                   VirginiaConservatives
# 10  group_1  group_2                CelebrateBuildBackBetter
# 11  group_1  group_2              GreenEnergyIsCostEffective
# 12  group_1  group_2            TellRepToNotRaiseOilGasTaxes
# 13  group_1  group_2                     GreenEnergyCapacity
# 14  group_1  group_2                          CleanOilAndGas
# 15  group_1  group_2          GreenEnergySupportsCommunities
# 16  group_1  group_2                              CutMethane
# 17  group_1  group_2                   CommerceCityDemocrats
# 18  group_1  group_2              DonationMatchingForClimate
# 19  group_1  group_2                    OilAndGasSupportJobs
# 20  group_1  group_2                          HazardsOfWells
# 21  group_1  group_2              ThankRepForBuildBackBetter
# 22  group_1  group_2         NuclearEnergyProvidesTaxRevenue
# 23  group_1  group_2                      BellbrookTaxRevolt
# 24  group_1  group_2              NuclearRevenueSupportsJobs
# 25  group_1  group_2                  OilAndGasProvidesWages
# 26  group_2  group_1                  ClimateChangeMovements
# 27  group_2  group_1              BuildBackBetterActCampaign
# 28  group_2  group_1                  ClimateChangeDonations
# 29  group_2  group_1                       OilAndGasTaxesBad
# 30  group_2  group_1  CallToActionAgainstOilAndGasIndustries
# 31  group_2  group_1       RenewableEnergyPromotionAndGrowth
# 32  group_2  group_1                 CarbonEmissionReduction
# 33  group_2  group_1                    CleanEnergyPromotion
# 34  group_2  group_1                   OilAndGasBoostEconomy
# 35  group_2  group_1         RenewableEnergyEconomicBenefits
# 36  group_2  group_1                BuildBackBetterActPassed
# 37  group_2  group_1                       PoliticalTraining
# 38  group_2  group_1                   LawmakersAndOilAndGas
# 39  group_2  group_1               NuclearPowerOtherBenefits
# 40  group_2  group_1                     PropertyTaxCampaign
# 41  group_2  group_1                      RightWingCampaigns
# 42  group_2  group_1            NuclearPowerEconomicBenefits
#
#                               anno_2_theme  jaccard_sim
# 0                   ClimateChangeMovements     0.065833
# 1                   ClimateChangeMovements     0.116155
# 2   CallToActionAgainstOilAndGasIndustries     0.047913
# 3   CallToActionAgainstOilAndGasIndustries     0.123789
# 4                   ClimateChangeMovements     0.119670
# 5        RenewableEnergyPromotionAndGrowth     0.226537
# 6                   ClimateChangeMovements     0.079797
# 7                   ClimateChangeMovements     0.099338
# 8   CallToActionAgainstOilAndGasIndustries     0.104914
# 9               BuildBackBetterActCampaign     0.048701
# 10                BuildBackBetterActPassed     0.136364
# 11                    CleanEnergyPromotion     0.021552
# 12                       OilAndGasTaxesBad     0.160237
# 13       RenewableEnergyPromotionAndGrowth     0.096706
# 14                    CleanEnergyPromotion     0.037190
# 15       RenewableEnergyPromotionAndGrowth     0.055435
# 16                 CarbonEmissionReduction     0.041056
# 17                     PropertyTaxCampaign     0.018182
# 18                  ClimateChangeDonations     0.004926
# 19                   OilAndGasBoostEconomy     0.250505
# 20                   LawmakersAndOilAndGas     0.011236
# 21              BuildBackBetterActCampaign     0.001502
# 22            NuclearPowerEconomicBenefits     0.166667
# 23                     PropertyTaxCampaign     0.050000
# 24               NuclearPowerOtherBenefits     0.080645
# 25                   OilAndGasBoostEconomy     0.050505
# 26                        ClimateEmergency     0.119670
# 27                CelebrateBuildBackBetter     0.071527
# 28          DemandClimateActionFromLeaders     0.052104
# 29            TellRepToNotRaiseOilGasTaxes     0.160237
# 30                   BellbrookWokeRadicals     0.123789
# 31                  GreenEnergyCreatesJobs     0.226537
# 32                     GreenEnergyCapacity     0.060669
# 33                  GreenEnergyCreatesJobs     0.070732
# 34                    OilAndGasSupportJobs     0.250505
# 35                  GreenEnergyCreatesJobs     0.043896
# 36                CelebrateBuildBackBetter     0.136364
# 37                         RestoreVirginia     0.028133
# 38            TellRepToNotRaiseOilGasTaxes     0.033473
# 39         NuclearEnergyProvidesTaxRevenue     0.081301
# 40                      BellbrookTaxRevolt     0.050000
# 41                   BellbrookWokeRadicals     0.101476
# 42         NuclearEnergyProvidesTaxRevenue     0.166667

# %% [markdown]
# ### 2.b. Getting max jaccard similarity for asynchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(asynchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(asynchronous_annotators))]
for anno_1_theme in filtered_df['anno_1_theme'].unique():
    if ('kmeans' not in anno_1_theme.lower()) and  ('Unknown' not in anno_1_theme.strip()) and (anno_1_theme != "None"):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('None')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('KMeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Asynchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
# Out:
# Asynchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.13
# Standard Deviation of Jaccard Similarity: 0.07

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                            anno_1_theme  \
# 0   async_1  async_3                  AdvocateForGreenEnergy
# 1   async_1  async_3                   ClimateActionDonation
# 2   async_1  async_3                                AntiWoke
# 3   async_1  async_3                        DemocratOutreach
# 4   async_1  async_2                        StopOilPollution
# 5   async_1  async_2                   GreenEnergySavesMoney
# 6   async_1  async_3   AdvocateForGreenEnergyPoliticalAction
# 7   async_1  async_3                          OilCreatesJobs
# 8   async_1  async_3                        GreenEnergyWorks
# 9   async_1  async_2                     GreenPowerExpensive
# 10  async_1  async_2                         NuclearAdvocacy
# 11  async_1  async_3                                 AntiTax
# 12  async_2  async_3       NeedQuickResponseForClimateCrisis
# 13  async_2  async_3               AgencyToStopClimateChange
# 14  async_2  async_1     PoliticalActivismForRenewableEnergy
# 15  async_2  async_3     EconomicAdvantagesOfRenewableEnergy
# 16  async_2  async_3         ChallengesFacingRenewableEnergy
# 17  async_2  async_1     ProtectFromHarmsCausedByFossilFuels
# 18  async_2  async_3            InroadsMadeByRenewableEnergy
# 19  async_2  async_3          CallsToInvestInRenewableEnergy
# 20  async_2  async_1           PoliticalActivismForOilAndGas
# 21  async_2  async_3               SupportForRenewableEnergy
# 22  async_2  async_1                     SupportForOilAndGas
# 23  async_2  async_1    DonateToSupportClimateChangeActivism
# 24  async_2  async_3                  InroadsMadeByOilAndGas
# 25  async_2  async_1           EconomicAdvantagesOfOilAndGas
# 26  async_2  async_3            SupportForBuildBackBetterAct
# 27  async_2  async_1                 SupportForNuclearEnergy
# 28  async_2  async_1       EconomicAdvantagesOfNuclearEnergy
# 29  async_2  async_1              InroadsMadeByNuclearEnergy
# 30  async_3  async_1                     TackleClimateChange
# 31  async_3  async_1  LegislatorsMustActAgainstClimateChange
# 32  async_3  async_1                AntiDemocraticCandidates
# 33  async_3  async_2                   RenewableEnergyGrowth
# 34  async_3  async_1                OilAndGasExtractionRisks
# 35  async_3  async_2                         ReduceEmissions
# 36  async_3  async_1                          BuildBetterAct
# 37  async_3  async_2                   NuclearEnergyBenefits
# 38  async_3  async_2                  ClimateChangeDonations
# 39  async_3  async_2     RenewableEnergyInfrastructureGrowth
# 40  async_3  async_1                           OilAndGasJobs
# 41  async_3  async_1                  NuclearEnergyEducation
# 42  async_3  async_2                         RestoreVirginia
# 43  async_3  async_1            VirginiaConservativeCampaign
# 44  async_3  async_2                  SouthwestGasInvestment
# 45  async_3  async_1                            OilAndGasTax
#
#                               anno_2_theme  jaccard_sim
# 0                      TackleClimateChange     0.216364
# 1                      TackleClimateChange     0.082636
# 2                 AntiDemocraticCandidates     0.121359
# 3                           BuildBetterAct     0.111406
# 4      ProtectFromHarmsCausedByFossilFuels     0.167476
# 5      EconomicAdvantagesOfRenewableEnergy     0.209765
# 6   LegislatorsMustActAgainstClimateChange     0.034729
# 7                            OilAndGasJobs     0.223790
# 8                    RenewableEnergyGrowth     0.097345
# 9          ChallengesFacingRenewableEnergy     0.060086
# 10       EconomicAdvantagesOfNuclearEnergy     0.276836
# 11                            OilAndGasTax     0.160448
# 12                     TackleClimateChange     0.078864
# 13                     TackleClimateChange     0.131095
# 14                  AdvocateForGreenEnergy     0.127273
# 15                   RenewableEnergyGrowth     0.209776
# 16                OilAndGasExtractionRisks     0.145495
# 17                        StopOilPollution     0.167476
# 18                   RenewableEnergyGrowth     0.088720
# 19  LegislatorsMustActAgainstClimateChange     0.068773
# 20                          OilCreatesJobs     0.118044
# 21                          BuildBetterAct     0.107417
# 22                          OilCreatesJobs     0.182310
# 23                   ClimateActionDonation     0.070248
# 24            VirginiaConservativeCampaign     0.028571
# 25                          OilCreatesJobs     0.175523
# 26                          BuildBetterAct     0.077586
# 27                         NuclearAdvocacy     0.154839
# 28                         NuclearAdvocacy     0.276836
# 29                         NuclearAdvocacy     0.048951
# 30                  AdvocateForGreenEnergy     0.216364
# 31                  AdvocateForGreenEnergy     0.156380
# 32                                AntiWoke     0.121359
# 33     EconomicAdvantagesOfRenewableEnergy     0.209776
# 34                          OilCreatesJobs     0.205443
# 35     EconomicAdvantagesOfRenewableEnergy     0.072289
# 36                        DemocratOutreach     0.111406
# 37     EconomicAdvantagesOfRenewableEnergy     0.150424
# 38    DonateToSupportClimateChangeActivism     0.032787
# 39            InroadsMadeByRenewableEnergy     0.055710
# 40                          OilCreatesJobs     0.223790
# 41                        DemocratOutreach     0.024096
# 42     PoliticalActivismForRenewableEnergy     0.021930
# 43                                AntiWoke     0.041825
# 44                     SupportForOilAndGas     0.014563
# 45                                 AntiTax     0.160448

# %% [markdown]
# ______

# %% [markdown]
# ## 3. Centroid Cosine Similarity

# %% [markdown]
# ### 3.a. Loading SBERT Vectors

# %%
sbert_vectors = np.load('./dataset/sbert.npy')

# %% [markdown]
# ### 3.b. Calculating centroids for sync + async experiments

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if 'kmeans' not in theme.lower() and theme.lower() != "None": 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim 
            results.append(result)

# %% [markdown]
# ### 3.c. Calculating synchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results: 
        for anno_2_result in anno_2_results:
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()) and (anno_2_result['theme'] != "None"): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()) and (anno_1_theme != "None"):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                            ~(filtered_df['anno_2_theme'].str.contains('None')) & 
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Synchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Synchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.95
# Standard Deviation of Centroid Cosine Similarity: 0.04
# anno_1          43
# anno_2          43
# anno_1_theme    43
# anno_2_theme    43
# cosine_sim      43
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                            anno_1_theme  \
# 0   group_1  group_2                                  GoBold
# 1   group_1  group_2          DemandClimateActionFromLeaders
# 2   group_1  group_2                  PublicLandExploitation
# 3   group_1  group_2                   BellbrookWokeRadicals
# 4   group_1  group_2                        ClimateEmergency
# 5   group_1  group_2                  GreenEnergyCreatesJobs
# 6   group_1  group_2                         RestoreVirginia
# 7   group_1  group_2                          AbandonedWells
# 8   group_1  group_2            AntiFossilFuelInfrastructure
# 9   group_1  group_2                   VirginiaConservatives
# 10  group_1  group_2                CelebrateBuildBackBetter
# 11  group_1  group_2              GreenEnergyIsCostEffective
# 12  group_1  group_2            TellRepToNotRaiseOilGasTaxes
# 13  group_1  group_2                     GreenEnergyCapacity
# 14  group_1  group_2                          CleanOilAndGas
# 15  group_1  group_2          GreenEnergySupportsCommunities
# 16  group_1  group_2                              CutMethane
# 17  group_1  group_2                   CommerceCityDemocrats
# 18  group_1  group_2              DonationMatchingForClimate
# 19  group_1  group_2                    OilAndGasSupportJobs
# 20  group_1  group_2                          HazardsOfWells
# 21  group_1  group_2              ThankRepForBuildBackBetter
# 22  group_1  group_2         NuclearEnergyProvidesTaxRevenue
# 23  group_1  group_2                      BellbrookTaxRevolt
# 24  group_1  group_2              NuclearRevenueSupportsJobs
# 25  group_1  group_2                  OilAndGasProvidesWages
# 26  group_2  group_1                  ClimateChangeMovements
# 27  group_2  group_1              BuildBackBetterActCampaign
# 28  group_2  group_1                  ClimateChangeDonations
# 29  group_2  group_1                       OilAndGasTaxesBad
# 30  group_2  group_1  CallToActionAgainstOilAndGasIndustries
# 31  group_2  group_1       RenewableEnergyPromotionAndGrowth
# 32  group_2  group_1                 CarbonEmissionReduction
# 33  group_2  group_1                    CleanEnergyPromotion
# 34  group_2  group_1                   OilAndGasBoostEconomy
# 35  group_2  group_1         RenewableEnergyEconomicBenefits
# 36  group_2  group_1                BuildBackBetterActPassed
# 37  group_2  group_1                       PoliticalTraining
# 38  group_2  group_1                   LawmakersAndOilAndGas
# 39  group_2  group_1               NuclearPowerOtherBenefits
# 40  group_2  group_1                     PropertyTaxCampaign
# 41  group_2  group_1                      RightWingCampaigns
# 42  group_2  group_1            NuclearPowerEconomicBenefits
#
#                               anno_2_theme  cosine_sim
# 0                   ClimateChangeDonations  0.97248197
# 1                   ClimateChangeMovements   0.9801712
# 2   CallToActionAgainstOilAndGasIndustries   0.9649988
# 3                       RightWingCampaigns  0.94298434
# 4                   ClimateChangeMovements   0.9587614
# 5        RenewableEnergyPromotionAndGrowth     0.99338
# 6               BuildBackBetterActCampaign  0.95462024
# 7   CallToActionAgainstOilAndGasIndustries   0.9556743
# 8   CallToActionAgainstOilAndGasIndustries  0.97245526
# 9               BuildBackBetterActCampaign  0.98708606
# 10                BuildBackBetterActPassed  0.95600617
# 11       RenewableEnergyPromotionAndGrowth  0.94183594
# 12                       OilAndGasTaxesBad   0.9680612
# 13       RenewableEnergyPromotionAndGrowth   0.9760397
# 14                    CleanEnergyPromotion   0.9178227
# 15       RenewableEnergyPromotionAndGrowth  0.98172224
# 16                 CarbonEmissionReduction   0.8976662
# 17              BuildBackBetterActCampaign   0.9135328
# 18                  ClimateChangeMovements   0.7925626
# 19                   OilAndGasBoostEconomy  0.99085695
# 20  CallToActionAgainstOilAndGasIndustries   0.8729517
# 21                BuildBackBetterActPassed    0.864351
# 22            NuclearPowerEconomicBenefits  0.97682357
# 23  CallToActionAgainstOilAndGasIndustries    0.877038
# 24            NuclearPowerEconomicBenefits   0.9722475
# 25                   OilAndGasBoostEconomy  0.97583675
# 26          DemandClimateActionFromLeaders   0.9801712
# 27                   VirginiaConservatives  0.98708606
# 28          DemandClimateActionFromLeaders   0.9740944
# 29            TellRepToNotRaiseOilGasTaxes   0.9680612
# 30            AntiFossilFuelInfrastructure  0.97245526
# 31                  GreenEnergyCreatesJobs     0.99338
# 32                                  GoBold   0.9596844
# 33                  GreenEnergyCreatesJobs   0.9838388
# 34                    OilAndGasSupportJobs  0.99085695
# 35                  GreenEnergyCreatesJobs   0.9504777
# 36                CelebrateBuildBackBetter  0.95600617
# 37                   BellbrookWokeRadicals   0.9186317
# 38            AntiFossilFuelInfrastructure   0.9316113
# 39         NuclearEnergyProvidesTaxRevenue   0.9693217
# 40                      BellbrookTaxRevolt   0.8684052
# 41                   BellbrookWokeRadicals  0.94298434
# 42         NuclearEnergyProvidesTaxRevenue  0.97682357

# %% [markdown]
# ### 3.d. Calculating asynchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results : 
        for anno_2_result in anno_2_results :
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()) and (anno_1_theme != 'None'):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                            ~(filtered_df['anno_2_theme'].str.contains('None')) & 
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Asynchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Asynchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.94
# Standard Deviation of Centroid Cosine Similarity: 0.06
# anno_1          92
# anno_2          92
# anno_1_theme    92
# anno_2_theme    92
# cosine_sim      92
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                  anno_1_theme  \
# 0   async_1  async_2        AdvocateForGreenEnergy
# 1   async_1  async_2         ClimateActionDonation
# 2   async_1  async_2                      AntiWoke
# 3   async_1  async_2              DemocratOutreach
# 4   async_1  async_2              StopOilPollution
# ..      ...      ...                           ...
# 87  async_3  async_2        NuclearEnergyEducation
# 88  async_3  async_2               RestoreVirginia
# 89  async_3  async_2  VirginiaConservativeCampaign
# 90  async_3  async_2        SouthwestGasInvestment
# 91  async_3  async_2                  OilAndGasTax
#
#                            anno_2_theme  cosine_sim
# 0             AgencyToStopClimateChange   0.9896499
# 1     NeedQuickResponseForClimateCrisis  0.97219014
# 2   PoliticalActivismForRenewableEnergy   0.9723315
# 3   PoliticalActivismForRenewableEnergy   0.9275266
# 4   ProtectFromHarmsCausedByFossilFuels   0.9860252
# ..                                  ...         ...
# 87  PoliticalActivismForRenewableEnergy   0.8928211
# 88  PoliticalActivismForRenewableEnergy  0.79759246
# 89  PoliticalActivismForRenewableEnergy  0.67207754
# 90        PoliticalActivismForOilAndGas  0.80390304
# 91        PoliticalActivismForOilAndGas   0.8769864
#
# [92 rows x 5 columns]

# %% [markdown]
# ____

# %% [markdown]
# ## 4. Group Average Cosine Similarity

# %%
results = {}
annotators = []

for annotator, df in annotator2df.items():
  results[annotator] = {}
  annotators.append(annotator)
  for i , theme in enumerate(df['name'].unique()):
      if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()):
          ids = df[df['name'] == theme]['tweet_id'].tolist()
          theme_vectors = sbert_vectors[ids]
          results[annotator][theme] = theme_vectors

# %% [markdown]
# ### 4.a. Calculating Group Average Similarities

# %%
global_average_sims = []

for (anno1 , anno2) in tqdm(itertools.combinations_with_replacement(annotators, 2)):
  anno1_themes = results[anno1]
  anno2_themes = results[anno2]
  for anno1_theme, anno1_theme_vectors in anno1_themes.items():
    for anno2_theme, anno2_theme_vectors in anno2_themes.items():
      s_time = time.time()
      cosine_sims = cosine_similarity(anno1_theme_vectors , anno2_theme_vectors)
      average_sim = np.average(cosine_sims)
      std_deviation = np.std(cosine_sims)
      global_average_sims.append({'anno1' : anno1 ,
                                  'anno2' : anno2 ,
                                  'anno1_theme' : anno1_theme ,
                                  'anno2_theme' : anno2_theme ,
                                  'average_sim' : average_sim ,
                                  'std_deviation' : std_deviation
                                  })
# Out:
# 0it [00:00, ?it/s]

# %%
global_average_sims
# Out:
# [{'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.34932762,
#   'std_deviation': 0.13314064},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.35483554,
#   'std_deviation': 0.13032691},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.26871988,
#   'std_deviation': 0.13096172},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.2749326,
#   'std_deviation': 0.13371937},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.32270235,
#   'std_deviation': 0.1280634},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.31017673,
#   'std_deviation': 0.12693925},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.31401873,
#   'std_deviation': 0.12993528},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.290239,
#   'std_deviation': 0.11854481},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.3010717,
#   'std_deviation': 0.1238333},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.29789063,
#   'std_deviation': 0.12168538},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.3203356,
#   'std_deviation': 0.11749966},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.27728292,
#   'std_deviation': 0.12475297},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.35483545,
#   'std_deviation': 0.1303269},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.39544725,
#   'std_deviation': 0.13998133},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.27284485,
#   'std_deviation': 0.12742695},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.27581447,
#   'std_deviation': 0.122253016},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.33713686,
#   'std_deviation': 0.13021848},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.2909115,
#   'std_deviation': 0.120855406},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.32563305,
#   'std_deviation': 0.1295717},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.27676773,
#   'std_deviation': 0.117938966},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.27729085,
#   'std_deviation': 0.116588004},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.28877604,
#   'std_deviation': 0.11890695},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.2965741,
#   'std_deviation': 0.1102533},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.28136128,
#   'std_deviation': 0.11717935},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.2687198,
#   'std_deviation': 0.13096173},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.2728448,
#   'std_deviation': 0.12742697},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.25409794,
#   'std_deviation': 0.13382713},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.25672457,
#   'std_deviation': 0.11751934},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.2715316,
#   'std_deviation': 0.1349622},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.24643409,
#   'std_deviation': 0.1380254},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.26359802,
#   'std_deviation': 0.12565592},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.25527462,
#   'std_deviation': 0.13977274},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.22260258,
#   'std_deviation': 0.13463852},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.2610904,
#   'std_deviation': 0.13377652},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.24276152,
#   'std_deviation': 0.12757921},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.271962,
#   'std_deviation': 0.12906079},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.27493262,
#   'std_deviation': 0.13371938},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.2758145,
#   'std_deviation': 0.122253016},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.25672457,
#   'std_deviation': 0.11751934},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.31821138,
#   'std_deviation': 0.14672135},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.24591759,
#   'std_deviation': 0.11640323},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.23356219,
#   'std_deviation': 0.12550713},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.2698138,
#   'std_deviation': 0.11853828},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.23581178,
#   'std_deviation': 0.11713117},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.2105525,
#   'std_deviation': 0.124987215},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.23356491,
#   'std_deviation': 0.11368364},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.22053388,
#   'std_deviation': 0.10663749},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.27838826,
#   'std_deviation': 0.11393072},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.32270247,
#   'std_deviation': 0.12806341},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.33713686,
#   'std_deviation': 0.13021848},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.2715316,
#   'std_deviation': 0.13496222},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.2459176,
#   'std_deviation': 0.11640322},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.3811766,
#   'std_deviation': 0.14050539},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.3012921,
#   'std_deviation': 0.12460417},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.30942446,
#   'std_deviation': 0.13365336},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.339365,
#   'std_deviation': 0.12655558},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.2722928,
#   'std_deviation': 0.118965894},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.3147283,
#   'std_deviation': 0.120261505},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.28477076,
#   'std_deviation': 0.111703284},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.29987386,
#   'std_deviation': 0.13072638},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.31017685,
#   'std_deviation': 0.12693927},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.29091144,
#   'std_deviation': 0.120855406},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.24643409,
#   'std_deviation': 0.1380254},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.23356219,
#   'std_deviation': 0.12550712},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.30129206,
#   'std_deviation': 0.12460417},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.33122838,
#   'std_deviation': 0.13390116},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.27485266,
#   'std_deviation': 0.12845817},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.32115093,
#   'std_deviation': 0.12986253},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.31661308,
#   'std_deviation': 0.12669994},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.32145116,
#   'std_deviation': 0.12918735},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.33100533,
#   'std_deviation': 0.11652182},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.27349332,
#   'std_deviation': 0.13719612},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.31401867,
#   'std_deviation': 0.12993528},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.32563305,
#   'std_deviation': 0.1295717},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.26359808,
#   'std_deviation': 0.12565592},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.26981384,
#   'std_deviation': 0.11853828},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.30942446,
#   'std_deviation': 0.13365336},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.27485263,
#   'std_deviation': 0.12845817},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.3107881,
#   'std_deviation': 0.14448373},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.27675718,
#   'std_deviation': 0.12425894},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.25957415,
#   'std_deviation': 0.12705512},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.27336085,
#   'std_deviation': 0.12386395},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.29223165,
#   'std_deviation': 0.13723823},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.27239162,
#   'std_deviation': 0.12305051},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.29023907,
#   'std_deviation': 0.11854478},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.2767677,
#   'std_deviation': 0.117938966},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.2552746,
#   'std_deviation': 0.13977276},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.23581178,
#   'std_deviation': 0.117131166},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.339365,
#   'std_deviation': 0.12655559},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.32115087,
#   'std_deviation': 0.12986252},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.27675718,
#   'std_deviation': 0.12425894},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.40522557,
#   'std_deviation': 0.14742436},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.28428632,
#   'std_deviation': 0.12051276},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.32311448,
#   'std_deviation': 0.12260731},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.289707,
#   'std_deviation': 0.109697096},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.3035779,
#   'std_deviation': 0.14197554},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.3010717,
#   'std_deviation': 0.123833306},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.27729085,
#   'std_deviation': 0.116588004},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.22260258,
#   'std_deviation': 0.13463852},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.2105525,
#   'std_deviation': 0.12498722},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.2722928,
#   'std_deviation': 0.118965894},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.31661308,
#   'std_deviation': 0.12669995},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.25957412,
#   'std_deviation': 0.12705512},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.28428632,
#   'std_deviation': 0.12051276},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.32697216,
#   'std_deviation': 0.13602649},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.28807312,
#   'std_deviation': 0.122985885},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.33379427,
#   'std_deviation': 0.11517703},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.22876717,
#   'std_deviation': 0.1289904},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.29789057,
#   'std_deviation': 0.12168539},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.288776,
#   'std_deviation': 0.11890695},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.26109034,
#   'std_deviation': 0.13377652},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.23356491,
#   'std_deviation': 0.11368364},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.3147283,
#   'std_deviation': 0.1202615},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.3214512,
#   'std_deviation': 0.12918735},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.27336085,
#   'std_deviation': 0.12386395},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.3231145,
#   'std_deviation': 0.122607306},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.28807312,
#   'std_deviation': 0.122985885},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.36220577,
#   'std_deviation': 0.14485809},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.306418,
#   'std_deviation': 0.11384171},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'GreenPowerExpensive',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.32266843,
#   'std_deviation': 0.13375871},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.32033563,
#   'std_deviation': 0.11749966},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.2965741,
#   'std_deviation': 0.1102533},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.24276155,
#   'std_deviation': 0.12757921},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.22053388,
#   'std_deviation': 0.10663749},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.28477076,
#   'std_deviation': 0.111703284},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.33100533,
#   'std_deviation': 0.116521806},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.29223165,
#   'std_deviation': 0.13723823},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.289707,
#   'std_deviation': 0.10969709},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.3337942,
#   'std_deviation': 0.11517703},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.306418,
#   'std_deviation': 0.11384171},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.501063,
#   'std_deviation': 0.17380872},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'NuclearAdvocacy',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.2417429,
#   'std_deviation': 0.11510618},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'AdvocateForGreenEnergy',
#   'average_sim': 0.2772829,
#   'std_deviation': 0.12475296},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'ClimateActionDonation',
#   'average_sim': 0.28136125,
#   'std_deviation': 0.11717935},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'AntiWoke',
#   'average_sim': 0.27196202,
#   'std_deviation': 0.12906079},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'DemocratOutreach',
#   'average_sim': 0.27838826,
#   'std_deviation': 0.11393072},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'StopOilPollution',
#   'average_sim': 0.29987383,
#   'std_deviation': 0.13072638},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'GreenEnergySavesMoney',
#   'average_sim': 0.27349332,
#   'std_deviation': 0.13719612},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'average_sim': 0.2723916,
#   'std_deviation': 0.12305051},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'OilCreatesJobs',
#   'average_sim': 0.30357787,
#   'std_deviation': 0.14197552},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'GreenEnergyWorks',
#   'average_sim': 0.22876717,
#   'std_deviation': 0.1289904},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'GreenPowerExpensive',
#   'average_sim': 0.32266843,
#   'std_deviation': 0.1337587},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'NuclearAdvocacy',
#   'average_sim': 0.2417429,
#   'std_deviation': 0.11510618},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'AntiTax',
#   'anno2_theme': 'AntiTax',
#   'average_sim': 0.36215246,
#   'std_deviation': 0.15683877},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GoBold',
#   'average_sim': 0.37344083,
#   'std_deviation': 0.12926301},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'DemandClimateActionFromLeaders',
#   'average_sim': 0.3789897,
#   'std_deviation': 0.13280381},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'PublicLandExploitation',
#   'average_sim': 0.31637305,
#   'std_deviation': 0.12650865},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'BellbrookWokeRadicals',
#   'average_sim': 0.24438319,
#   'std_deviation': 0.122551434},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'ClimateEmergency',
#   'average_sim': 0.36495402,
#   'std_deviation': 0.13075522},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergyCreatesJobs',
#   'average_sim': 0.34004775,
#   'std_deviation': 0.12637915},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'RestoreVirginia',
#   'average_sim': 0.29660106,
#   'std_deviation': 0.13643381},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AbandonedWells',
#   'average_sim': 0.29095855,
#   'std_deviation': 0.1252009},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'AntiFossilFuelInfrastructure',
#   'average_sim': 0.31314766,
#   'std_deviation': 0.122180514},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'VirginiaConservatives',
#   'average_sim': 0.29814777,
#   'std_deviation': 0.13462853},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'CelebrateBuildBackBetter',
#   'average_sim': 0.3846426,
#   'std_deviation': 0.13654487},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergyIsCostEffective',
#   'average_sim': 0.3161756,
#   'std_deviation': 0.11686395},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'TellRepToNotRaiseOilGasTaxes',
#   'average_sim': 0.30743015,
#   'std_deviation': 0.12777147},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergyCapacity',
#   'average_sim': 0.3056815,
#   'std_deviation': 0.12575328},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'CleanOilAndGas',
#   'average_sim': 0.3167817,
#   'std_deviation': 0.12825912},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'GreenEnergySupportsCommunities',
#   'average_sim': 0.3321768,
#   'std_deviation': 0.1257633},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'CutMethane',
#   'average_sim': 0.34597751,
#   'std_deviation': 0.12719993},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'CommerceCityDemocrats',
#   'average_sim': 0.27800924,
#   'std_deviation': 0.12790786},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'DonationMatchingForClimate',
#   'average_sim': 0.33369103,
#   'std_deviation': 0.12264637},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'OilAndGasSupportJobs',
#   'average_sim': 0.29570383,
#   'std_deviation': 0.11686654},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'HazardsOfWells',
#   'average_sim': 0.27615976,
#   'std_deviation': 0.12094665},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'ThankRepForBuildBackBetter',
#   'average_sim': 0.39544633,
#   'std_deviation': 0.13642503},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'NuclearEnergyProvidesTaxRevenue',
#   'average_sim': 0.3166855,
#   'std_deviation': 0.117786944},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'BellbrookTaxRevolt',
#   'average_sim': 0.25419766,
#   'std_deviation': 0.113352336},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'NuclearRevenueSupportsJobs',
#   'average_sim': 0.30634877,
#   'std_deviation': 0.115673006},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AdvocateForGreenEnergy',
#   'anno2_theme': 'OilAndGasProvidesWages',
#   'average_sim': 0.2881837,
#   'std_deviation': 0.1159753},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GoBold',
#   'average_sim': 0.38276613,
#   'std_deviation': 0.1270004},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'DemandClimateActionFromLeaders',
#   'average_sim': 0.40194225,
#   'std_deviation': 0.12906237},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'PublicLandExploitation',
#   'average_sim': 0.3248241,
#   'std_deviation': 0.13020827},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'BellbrookWokeRadicals',
#   'average_sim': 0.25089464,
#   'std_deviation': 0.11686705},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'ClimateEmergency',
#   'average_sim': 0.40563604,
#   'std_deviation': 0.1289004},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergyCreatesJobs',
#   'average_sim': 0.32227442,
#   'std_deviation': 0.12090392},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'RestoreVirginia',
#   'average_sim': 0.30336526,
#   'std_deviation': 0.13239633},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AbandonedWells',
#   'average_sim': 0.29309893,
#   'std_deviation': 0.12510782},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'AntiFossilFuelInfrastructure',
#   'average_sim': 0.31578344,
#   'std_deviation': 0.12388502},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'VirginiaConservatives',
#   'average_sim': 0.2998118,
#   'std_deviation': 0.13494001},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'CelebrateBuildBackBetter',
#   'average_sim': 0.37392557,
#   'std_deviation': 0.12203727},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergyIsCostEffective',
#   'average_sim': 0.29058716,
#   'std_deviation': 0.10740892},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'TellRepToNotRaiseOilGasTaxes',
#   'average_sim': 0.30705366,
#   'std_deviation': 0.1202411},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergyCapacity',
#   'average_sim': 0.28118494,
#   'std_deviation': 0.11932548},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'CleanOilAndGas',
#   'average_sim': 0.30369386,
#   'std_deviation': 0.12608482},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'GreenEnergySupportsCommunities',
#   'average_sim': 0.31750852,
#   'std_deviation': 0.11959309},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'CutMethane',
#   'average_sim': 0.35076237,
#   'std_deviation': 0.122335136},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'CommerceCityDemocrats',
#   'average_sim': 0.2797749,
#   'std_deviation': 0.12559561},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'DonationMatchingForClimate',
#   'average_sim': 0.3970651,
#   'std_deviation': 0.15360571},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'OilAndGasSupportJobs',
#   'average_sim': 0.27650028,
#   'std_deviation': 0.11493211},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'HazardsOfWells',
#   'average_sim': 0.2837916,
#   'std_deviation': 0.12393428},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'ThankRepForBuildBackBetter',
#   'average_sim': 0.38332003,
#   'std_deviation': 0.118672},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'NuclearEnergyProvidesTaxRevenue',
#   'average_sim': 0.28506264,
#   'std_deviation': 0.10859631},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'BellbrookTaxRevolt',
#   'average_sim': 0.2539228,
#   'std_deviation': 0.11098243},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'NuclearRevenueSupportsJobs',
#   'average_sim': 0.2745954,
#   'std_deviation': 0.10291118},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'ClimateActionDonation',
#   'anno2_theme': 'OilAndGasProvidesWages',
#   'average_sim': 0.2715831,
#   'std_deviation': 0.113247946},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GoBold',
#   'average_sim': 0.27938485,
#   'std_deviation': 0.1336171},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'DemandClimateActionFromLeaders',
#   'average_sim': 0.29932675,
#   'std_deviation': 0.12351855},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'PublicLandExploitation',
#   'average_sim': 0.2768673,
#   'std_deviation': 0.13055365},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'BellbrookWokeRadicals',
#   'average_sim': 0.25080737,
#   'std_deviation': 0.13076971},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'ClimateEmergency',
#   'average_sim': 0.27455798,
#   'std_deviation': 0.12784432},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergyCreatesJobs',
#   'average_sim': 0.2533083,
#   'std_deviation': 0.13572513},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'RestoreVirginia',
#   'average_sim': 0.25020885,
#   'std_deviation': 0.12344507},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AbandonedWells',
#   'average_sim': 0.24635628,
#   'std_deviation': 0.13048667},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'AntiFossilFuelInfrastructure',
#   'average_sim': 0.28118408,
#   'std_deviation': 0.13071547},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'VirginiaConservatives',
#   'average_sim': 0.25227883,
#   'std_deviation': 0.13076128},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'CelebrateBuildBackBetter',
#   'average_sim': 0.30641165,
#   'std_deviation': 0.11464473},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergyIsCostEffective',
#   'average_sim': 0.23993573,
#   'std_deviation': 0.13930032},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'TellRepToNotRaiseOilGasTaxes',
#   'average_sim': 0.2851611,
#   'std_deviation': 0.13753411},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergyCapacity',
#   'average_sim': 0.22305481,
#   'std_deviation': 0.13691118},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'CleanOilAndGas',
#   'average_sim': 0.2456974,
#   'std_deviation': 0.1409138},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'GreenEnergySupportsCommunities',
#   'average_sim': 0.251803,
#   'std_deviation': 0.13204798},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'CutMethane',
#   'average_sim': 0.2681693,
#   'std_deviation': 0.14026126},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'CommerceCityDemocrats',
#   'average_sim': 0.24956338,
#   'std_deviation': 0.12549217},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'DonationMatchingForClimate',
#   'average_sim': 0.25560263,
#   'std_deviation': 0.11356966},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'OilAndGasSupportJobs',
#   'average_sim': 0.25447458,
#   'std_deviation': 0.14315058},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'HazardsOfWells',
#   'average_sim': 0.23341903,
#   'std_deviation': 0.13325235},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'ThankRepForBuildBackBetter',
#   'average_sim': 0.31914592,
#   'std_deviation': 0.10700146},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'NuclearEnergyProvidesTaxRevenue',
#   'average_sim': 0.2331579,
#   'std_deviation': 0.13162032},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'BellbrookTaxRevolt',
#   'average_sim': 0.25320703,
#   'std_deviation': 0.12794547},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'NuclearRevenueSupportsJobs',
#   'average_sim': 0.23213424,
#   'std_deviation': 0.12537503},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'AntiWoke',
#   'anno2_theme': 'OilAndGasProvidesWages',
#   'average_sim': 0.24414538,
#   'std_deviation': 0.14254965},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GoBold',
#   'average_sim': 0.27718097,
#   'std_deviation': 0.13141559},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'DemandClimateActionFromLeaders',
#   'average_sim': 0.3200347,
#   'std_deviation': 0.12821476},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'PublicLandExploitation',
#   'average_sim': 0.25900614,
#   'std_deviation': 0.11268474},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'BellbrookWokeRadicals',
#   'average_sim': 0.26391506,
#   'std_deviation': 0.114829786},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'ClimateEmergency',
#   'average_sim': 0.26686722,
#   'std_deviation': 0.11919124},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergyCreatesJobs',
#   'average_sim': 0.25019893,
#   'std_deviation': 0.13105157},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'RestoreVirginia',
#   'average_sim': 0.283247,
#   'std_deviation': 0.13033679},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AbandonedWells',
#   'average_sim': 0.23098214,
#   'std_deviation': 0.11602536},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'AntiFossilFuelInfrastructure',
#   'average_sim': 0.25921503,
#   'std_deviation': 0.11187526},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'VirginiaConservatives',
#   'average_sim': 0.25978255,
#   'std_deviation': 0.12728244},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'CelebrateBuildBackBetter',
#   'average_sim': 0.38831618,
#   'std_deviation': 0.18300602},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergyIsCostEffective',
#   'average_sim': 0.21345577,
#   'std_deviation': 0.11641227},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'TellRepToNotRaiseOilGasTaxes',
#   'average_sim': 0.27981248,
#   'std_deviation': 0.11815561},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergyCapacity',
#   'average_sim': 0.2076863,
#   'std_deviation': 0.118585855},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'CleanOilAndGas',
#   'average_sim': 0.21967945,
#   'std_deviation': 0.11815351},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'GreenEnergySupportsCommunities',
#   'average_sim': 0.25320062,
#   'std_deviation': 0.12612669},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'CutMethane',
#   'average_sim': 0.24351853,
#   'std_deviation': 0.12574387},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'CommerceCityDemocrats',
#   'average_sim': 0.27430022,
#   'std_deviation': 0.12013798},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'DonationMatchingForClimate',
#   'average_sim': 0.27594376,
#   'std_deviation': 0.10058425},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'OilAndGasSupportJobs',
#   'average_sim': 0.23498385,
#   'std_deviation': 0.11895973},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'HazardsOfWells',
#   'average_sim': 0.20846792,
#   'std_deviation': 0.11155851},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'ThankRepForBuildBackBetter',
#   'average_sim': 0.43075898,
#   'std_deviation': 0.17324565},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'NuclearEnergyProvidesTaxRevenue',
#   'average_sim': 0.20832998,
#   'std_deviation': 0.10700365},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'BellbrookTaxRevolt',
#   'average_sim': 0.26019233,
#   'std_deviation': 0.11267224},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'NuclearRevenueSupportsJobs',
#   'average_sim': 0.21051839,
#   'std_deviation': 0.099592246},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'OilAndGasProvidesWages',
#   'average_sim': 0.2187823,
#   'std_deviation': 0.11306492},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GoBold',
#   'average_sim': 0.34415835,
#   'std_deviation': 0.123787045},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'DemandClimateActionFromLeaders',
#   'average_sim': 0.3510775,
#   'std_deviation': 0.12786736},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'PublicLandExploitation',
#   'average_sim': 0.3599335,
#   'std_deviation': 0.1371901},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'BellbrookWokeRadicals',
#   'average_sim': 0.24669667,
#   'std_deviation': 0.12678407},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'ClimateEmergency',
#   'average_sim': 0.34259018,
#   'std_deviation': 0.12506643},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenEnergyCreatesJobs',
#   'average_sim': 0.30602393,
#   'std_deviation': 0.119987555},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'RestoreVirginia',
#   'average_sim': 0.26390967,
#   'std_deviation': 0.12877998},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AbandonedWells',
#   'average_sim': 0.31271312,
#   'std_deviation': 0.13264456},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AntiFossilFuelInfrastructure',
#   'average_sim': 0.34566504,
#   'std_deviation': 0.13136105},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'VirginiaConservatives',
#   'average_sim': 0.28910717,
#   'std_deviation': 0.13199694},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'CelebrateBuildBackBetter',
#   'average_sim': 0.3295367,
#   'std_deviation': 0.11022023},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenEnergyIsCostEffective',
#   'average_sim': 0.30046493,
#   'std_deviation': 0.11676499},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'TellRepToNotRaiseOilGasTaxes',
#   'average_sim': 0.33901685,
#   'std_deviation': 0.13261543},
#  {'anno1': 'async_1',
#   'anno2': 'group_1',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'GreenEnergyCapacity',
#   'average_sim': 0.2771855,
#   'std_deviation': 0.12161192},
# ...
#   'std_deviation': 0.12502274},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'EconomicAdvantagesOfOilAndGas',
#   'average_sim': 0.22822516,
#   'std_deviation': 0.119682975},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'SupportForBuildBackBetterAct',
#   'average_sim': 0.3884649,
#   'std_deviation': 0.18162088},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'SupportForNuclearEnergy',
#   'average_sim': 0.22578156,
#   'std_deviation': 0.104517244},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'EconomicAdvantagesOfNuclearEnergy',
#   'average_sim': 0.20751522,
#   'std_deviation': 0.10540059},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'DemocratOutreach',
#   'anno2_theme': 'InroadsMadeByNuclearEnergy',
#   'average_sim': 0.20224193,
#   'std_deviation': 0.11266946},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'NeedQuickResponseForClimateCrisis',
#   'average_sim': 0.33151948,
#   'std_deviation': 0.1279787},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'AgencyToStopClimateChange',
#   'average_sim': 0.31043148,
#   'std_deviation': 0.13159111},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'PoliticalActivismForRenewableEnergy',
#   'average_sim': 0.3036001,
#   'std_deviation': 0.13651536},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'EconomicAdvantagesOfRenewableEnergy',
#   'average_sim': 0.2976647,
#   'std_deviation': 0.12258864},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'ChallengesFacingRenewableEnergy',
#   'average_sim': 0.30678654,
#   'std_deviation': 0.13348459},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'ProtectFromHarmsCausedByFossilFuels',
#   'average_sim': 0.3747488,
#   'std_deviation': 0.13624978},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'InroadsMadeByRenewableEnergy',
#   'average_sim': 0.29537323,
#   'std_deviation': 0.12314697},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'CallsToInvestInRenewableEnergy',
#   'average_sim': 0.333979,
#   'std_deviation': 0.13371526},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'PoliticalActivismForOilAndGas',
#   'average_sim': 0.30377322,
#   'std_deviation': 0.13809718},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'SupportForRenewableEnergy',
#   'average_sim': 0.31537893,
#   'std_deviation': 0.12450846},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'SupportForOilAndGas',
#   'average_sim': 0.33078733,
#   'std_deviation': 0.1323469},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'DonateToSupportClimateChangeActivism',
#   'average_sim': 0.29608703,
#   'std_deviation': 0.12964012},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'InroadsMadeByOilAndGas',
#   'average_sim': 0.30833542,
#   'std_deviation': 0.13052478},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'EconomicAdvantagesOfOilAndGas',
#   'average_sim': 0.3206348,
#   'std_deviation': 0.12634826},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'SupportForBuildBackBetterAct',
#   'average_sim': 0.33530512,
#   'std_deviation': 0.117293954},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'SupportForNuclearEnergy',
#   'average_sim': 0.27787644,
#   'std_deviation': 0.11741597},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'EconomicAdvantagesOfNuclearEnergy',
#   'average_sim': 0.27366757,
#   'std_deviation': 0.10673245},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'StopOilPollution',
#   'anno2_theme': 'InroadsMadeByNuclearEnergy',
#   'average_sim': 0.27265474,
#   'std_deviation': 0.12209404},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'NeedQuickResponseForClimateCrisis',
#   'average_sim': 0.2903782,
#   'std_deviation': 0.1242383},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'AgencyToStopClimateChange',
#   'average_sim': 0.28766507,
#   'std_deviation': 0.12962687},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'PoliticalActivismForRenewableEnergy',
#   'average_sim': 0.27508894,
#   'std_deviation': 0.13478732},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'EconomicAdvantagesOfRenewableEnergy',
#   'average_sim': 0.32246947,
#   'std_deviation': 0.12999788},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'ChallengesFacingRenewableEnergy',
#   'average_sim': 0.27649978,
#   'std_deviation': 0.1309513},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'ProtectFromHarmsCausedByFossilFuels',
#   'average_sim': 0.30601725,
#   'std_deviation': 0.12531061},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'InroadsMadeByRenewableEnergy',
#   'average_sim': 0.3154098,
#   'std_deviation': 0.12829107},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'CallsToInvestInRenewableEnergy',
#   'average_sim': 0.31217933,
#   'std_deviation': 0.13470276},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'PoliticalActivismForOilAndGas',
#   'average_sim': 0.2719079,
#   'std_deviation': 0.13861623},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'SupportForRenewableEnergy',
#   'average_sim': 0.3260137,
#   'std_deviation': 0.13009222},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'SupportForOilAndGas',
#   'average_sim': 0.3118932,
#   'std_deviation': 0.13613637},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'DonateToSupportClimateChangeActivism',
#   'average_sim': 0.25022587,
#   'std_deviation': 0.10964833},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'InroadsMadeByOilAndGas',
#   'average_sim': 0.31016457,
#   'std_deviation': 0.14818825},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'EconomicAdvantagesOfOilAndGas',
#   'average_sim': 0.32088673,
#   'std_deviation': 0.1362812},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'SupportForBuildBackBetterAct',
#   'average_sim': 0.33423182,
#   'std_deviation': 0.1219284},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'SupportForNuclearEnergy',
#   'average_sim': 0.31827703,
#   'std_deviation': 0.124394864},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'EconomicAdvantagesOfNuclearEnergy',
#   'average_sim': 0.33974195,
#   'std_deviation': 0.115101136},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergySavesMoney',
#   'anno2_theme': 'InroadsMadeByNuclearEnergy',
#   'average_sim': 0.3151715,
#   'std_deviation': 0.12294041},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'NeedQuickResponseForClimateCrisis',
#   'average_sim': 0.3248513,
#   'std_deviation': 0.13368624},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'AgencyToStopClimateChange',
#   'average_sim': 0.2988227,
#   'std_deviation': 0.13114041},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'PoliticalActivismForRenewableEnergy',
#   'average_sim': 0.30431715,
#   'std_deviation': 0.12895599},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'EconomicAdvantagesOfRenewableEnergy',
#   'average_sim': 0.28209603,
#   'std_deviation': 0.12841313},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'ChallengesFacingRenewableEnergy',
#   'average_sim': 0.27599186,
#   'std_deviation': 0.12865603},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'ProtectFromHarmsCausedByFossilFuels',
#   'average_sim': 0.3122447,
#   'std_deviation': 0.13242032},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'InroadsMadeByRenewableEnergy',
#   'average_sim': 0.285566,
#   'std_deviation': 0.12894773},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'CallsToInvestInRenewableEnergy',
#   'average_sim': 0.3269125,
#   'std_deviation': 0.13156474},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'PoliticalActivismForOilAndGas',
#   'average_sim': 0.27285835,
#   'std_deviation': 0.122193076},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'SupportForRenewableEnergy',
#   'average_sim': 0.3161277,
#   'std_deviation': 0.12471821},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'SupportForOilAndGas',
#   'average_sim': 0.27462986,
#   'std_deviation': 0.12518783},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'DonateToSupportClimateChangeActivism',
#   'average_sim': 0.30145428,
#   'std_deviation': 0.121723555},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'InroadsMadeByOilAndGas',
#   'average_sim': 0.26174733,
#   'std_deviation': 0.12999398},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'EconomicAdvantagesOfOilAndGas',
#   'average_sim': 0.26555648,
#   'std_deviation': 0.12344683},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'SupportForBuildBackBetterAct',
#   'average_sim': 0.3422202,
#   'std_deviation': 0.1228754},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'SupportForNuclearEnergy',
#   'average_sim': 0.28369665,
#   'std_deviation': 0.1398001},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'EconomicAdvantagesOfNuclearEnergy',
#   'average_sim': 0.28537023,
#   'std_deviation': 0.14271821},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'AdvocateForGreenEnergyPoliticalAction',
#   'anno2_theme': 'InroadsMadeByNuclearEnergy',
#   'average_sim': 0.28627694,
#   'std_deviation': 0.1451432},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'NeedQuickResponseForClimateCrisis',
#   'average_sim': 0.27455074,
#   'std_deviation': 0.1152144},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'AgencyToStopClimateChange',
#   'average_sim': 0.27842245,
#   'std_deviation': 0.12345531},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'PoliticalActivismForRenewableEnergy',
#   'average_sim': 0.27353537,
#   'std_deviation': 0.12915058},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'EconomicAdvantagesOfRenewableEnergy',
#   'average_sim': 0.30393118,
#   'std_deviation': 0.123910435},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'ChallengesFacingRenewableEnergy',
#   'average_sim': 0.27967376,
#   'std_deviation': 0.12991321},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'ProtectFromHarmsCausedByFossilFuels',
#   'average_sim': 0.34949422,
#   'std_deviation': 0.12655044},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'InroadsMadeByRenewableEnergy',
#   'average_sim': 0.28234455,
#   'std_deviation': 0.11686407},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'CallsToInvestInRenewableEnergy',
#   'average_sim': 0.30196494,
#   'std_deviation': 0.12741607},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'PoliticalActivismForOilAndGas',
#   'average_sim': 0.3237724,
#   'std_deviation': 0.15957361},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'SupportForRenewableEnergy',
#   'average_sim': 0.30047128,
#   'std_deviation': 0.12027638},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'SupportForOilAndGas',
#   'average_sim': 0.3851068,
#   'std_deviation': 0.15295303},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'DonateToSupportClimateChangeActivism',
#   'average_sim': 0.23307574,
#   'std_deviation': 0.10504175},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'InroadsMadeByOilAndGas',
#   'average_sim': 0.3516659,
#   'std_deviation': 0.15001366},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'EconomicAdvantagesOfOilAndGas',
#   'average_sim': 0.38210475,
#   'std_deviation': 0.15551649},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'SupportForBuildBackBetterAct',
#   'average_sim': 0.31976297,
#   'std_deviation': 0.10385483},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'SupportForNuclearEnergy',
#   'average_sim': 0.28676295,
#   'std_deviation': 0.11531709},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'EconomicAdvantagesOfNuclearEnergy',
#   'average_sim': 0.2900702,
#   'std_deviation': 0.10792962},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'OilCreatesJobs',
#   'anno2_theme': 'InroadsMadeByNuclearEnergy',
#   'average_sim': 0.25896922,
#   'std_deviation': 0.11090915},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'NeedQuickResponseForClimateCrisis',
#   'average_sim': 0.27281794,
#   'std_deviation': 0.122664616},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'AgencyToStopClimateChange',
#   'average_sim': 0.27302232,
#   'std_deviation': 0.12718882},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'PoliticalActivismForRenewableEnergy',
#   'average_sim': 0.2561731,
#   'std_deviation': 0.1336281},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'GreenEnergyWorks',
#   'anno2_theme': 'EconomicAdvantagesOfRenewableEnergy',
#   'average_sim': 0.31421912,
#   'std_deviation': 0.1271162},
#  ...]

# %%
global_average_df = pd.DataFrame(global_average_sims)

# %% [markdown]
# ### 4.b. Calculating Synchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                            ~(filtered_df['anno2_theme'].str.contains('None')) & 
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Synchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Synchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.37
# Standard Deviation of Group Cosine Similarity: 0.07
# anno1            26
# anno2            26
# anno1_theme      26
# anno2_theme      26
# average_sim      26
# std_deviation    26
# dtype: int64

# %% [markdown]
# ### 4.c. Calculating Asynchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                            ~(filtered_df['anno2_theme'].str.contains('None')) & 
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Asynchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Asynchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.36
# Standard Deviation of Group Cosine Similarity: 0.06
# anno1            40
# anno2            40
# anno1_theme      40
# anno2_theme      40
# average_sim      40
# std_deviation    40
# dtype: int64

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Getting top 25th percentile of closest vectors to each centroid

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()) and (theme != "None"): 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            result['tweets'] = df[df['name'] == theme]['text'].tolist()

            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim.squeeze() 
            results.append(result)

# %%
top_25_results = {'top_25_tweets':[],
                  'top_25_vectors' : [], 
                  'theme' : [], 
                  'annotator' : []}

for result in results: 

    m = np.percentile(result['cosine_sim'] , 25)
    n = np.percentile(result['cosine_sim'] , 25)
    top_25_indices = np.where(result['cosine_sim']<m)
    # top_25_indices = np.where(np.logical_and(result['cosine_sim']>n , result['cosine_sim']<m))
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results['top_25_tweets'].extend(top_25_tweets)
    top_25_results['top_25_vectors'].extend(top_25_vectors )
    top_25_results['theme'].extend([theme]*top_25_tweets.shape[0])
    top_25_results['annotator'].extend([annotator]*top_25_tweets.shape[0])


top_25_df = pd.DataFrame(top_25_results, columns=['theme' , 'annotator' , 'top_25_tweets'])

# %% [markdown]
# ### 4.a. Random Sampling rows for manual annotations

# %%
sync_top_25 = top_25_df[top_25_df['annotator'].isin(synchronous_annotators)].sample(n=1000)[['theme' , 'top_25_tweets']]
async_top_25 = top_25_df[top_25_df['annotator'].isin(asynchronous_annotators)].sample(n=1000)[['theme' , 'top_25_tweets']]

sync_top_25.to_csv('./dataset/generated_samples/laca_sync_sample_0to25.csv' , index=False, sep='\t')
async_top_25.to_csv('./dataset/generated_samples/laca_async_sample_0to25.csv' , index=False, sep='\t')

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Calculating Intra- and Inter-cluster Similarity

# %%
top_25_results = {}

for result in results: 

    top_25_results[result['theme']] = {}

    m = np.percentile(result['cosine_sim'] , 75)
    top_25_indices = np.where(result['cosine_sim']>m)
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results[theme]['top_25_tweets'] = (top_25_tweets)
    top_25_results[theme]['top_25_vectors'] = (top_25_vectors )
    top_25_results[theme]['annotator'] = (annotator)

# %% [markdown]
# ### 5.a. Calculating similarities for top 25th percentile clusters

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_25_average_sims = []

for anno_1_theme , anno1_top_25 in tqdm(top_25_results.items()): 
    for anno_2_theme , anno2_top_25 in top_25_results.items(): 

        anno1_top_25_vectors = anno1_top_25['top_25_vectors']
        anno2_top_25_vectors = anno2_top_25['top_25_vectors']

        cosine_sims = cosine_similarity(anno1_top_25_vectors , anno2_top_25_vectors)
        average_sim = np.average(cosine_sims)
        std_deviation = np.std(cosine_sims)

        top_25_average_sims.append({'anno_1' : anno1_top_25['annotator'] , 
                                   'anno_2' : anno2_top_25['annotator'], 
                                   'anno_1_theme' : anno_1_theme,
                                   'anno_2_theme' : anno_2_theme,
                                   'average_sim' : average_sim , 
                                   'std_dev_sim' : std_deviation})
# Out:
#   0%|          | 0/87 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 11
#       8 anno1_top_25_vectors = anno1_top_25['top_25_vectors']
#       9 anno2_top_25_vectors = anno2_top_25['top_25_vectors']
# ---> 11 cosine_sims = cosine_similarity(anno1_top_25_vectors , anno2_top_25_vectors)
#      12 average_sim = np.average(cosine_sims)
#      13 std_deviation = np.std(cosine_sims)
#
# File /opt/homebrew/anaconda3/envs/eval/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/homebrew/anaconda3/envs/eval/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:1657, in cosine_similarity(X, Y, dense_output)
#    1613 """Compute cosine similarity between samples in X and Y.
#    1614
#    1615 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1653        [0.57..., 0.81...]])
#    1654 """
#    1655 # to avoid recursive import
# -> 1657 X, Y = check_pairwise_arrays(X, Y)
#    1659 X_normalized = normalize(X, copy=True)
#    1660 if X is Y:
#
# File /opt/homebrew/anaconda3/envs/eval/lib/python3.12/site-packages/sklearn/metrics/pairwise.py:172, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     163 else:
#     164     X = check_array(
#     165         X,
#     166         accept_sparse=accept_sparse,
#    (...)
#     170         estimator=estimator,
#     171     )
# --> 172     Y = check_array(
#     173         Y,
#     174         accept_sparse=accept_sparse,
#     175         dtype=dtype,
#     176         copy=copy,
#     177         force_all_finite=force_all_finite,
#     178         estimator=estimator,
#     179     )
#     181 if precomputed:
#     182     if X.shape[1] != Y.shape[0]:
#
# File /opt/homebrew/anaconda3/envs/eval/lib/python3.12/site-packages/sklearn/utils/validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 768)) while a minimum of 1 is required by check_pairwise_arrays.

# %%
top_25_average_df = pd.DataFrame(top_25_average_sims)
top_25_average_df
# Out:
#          anno_1     anno_2                           anno_1_theme  \
# 0     alexandra  alexandra  Receiving_first_dose_of_covid_vaccine
# 1     alexandra  alexandra  Receiving_first_dose_of_covid_vaccine
# 2     alexandra  alexandra  Receiving_first_dose_of_covid_vaccine
# 3     alexandra  alexandra  Receiving_first_dose_of_covid_vaccine
# 4     alexandra  alexandra  Receiving_first_dose_of_covid_vaccine
# ...         ...        ...                                    ...
# 3595   sync2_22   sync2_22                      online_references
# 3596   sync2_22   sync2_22                      online_references
# 3597   sync2_22   sync2_22                      online_references
# 3598   sync2_22   sync2_22                      online_references
# 3599   sync2_22   sync2_22                      online_references
#
#                                            anno_2_theme  average_sim  \
# 0                 Receiving_first_dose_of_covid_vaccine     0.719753
# 1                        Praising_Government_Leadership     0.567607
# 2     Providing_resources_to_those_who_are_not_invol...     0.564993
# 3                Vaccine_accessibility_and_distribution     0.537902
# 4                 Praising_frontline_healthcare_workers     0.647123
# ...                                                 ...          ...
# 3595                                    vaccine_rollout     0.522907
# 3596                                   vaccine_efficacy     0.477832
# 3597                                 vaccine_first_dose     0.482601
# 3598                                   vaccine_symptoms     0.420470
# 3599                                  online_references     0.488203
#
#       std_dev_sim
# 0        0.071794
# 1        0.084653
# 2        0.074919
# 3        0.074487
# 4        0.074139
# ...           ...
# 3595     0.099415
# 3596     0.120104
# 3597     0.116718
# 3598     0.119692
# 3599     0.116059
#
# [3600 rows x 6 columns]

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']==top_25_average_df['anno_2_theme'])]

# %% [markdown]
# ### 5.b. Intra- and Inter-theme similarities for top 25th percentile subsets in synchronous and asynchronous experiments

# %%
print(f"Synchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% intra theme similarity average: 0.63
# Synchronous top 25% intra theme similarity standard deviation: 0.07
# Asynchronous top 25% intra theme similarity average: 0.63
# Asynchronous top 25% intra theme similarity standard deviation: 0.05

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']!=top_25_average_df['anno_2_theme'])]

# %%
print(f"Synchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% inter theme similarity average: 0.55
# Synchronous top 25% inter theme similarity standard deviation: 0.05
# Asynchronous top 25% inter theme similarity average: 0.54
# Asynchronous top 25% inter theme similarity standard deviation: 0.05

# %% [markdown]
# ### 5.c. Intra- and Inter-theme similarities for whole set in synchronous and asynchronous experiments

# %%
global_average_df = pd.DataFrame(global_average_sims)

intra_global_average_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']==global_average_df['anno2_theme'])] 


print(f"Synchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global intra theme similarity average: 0.44
# Synchronous global intra theme similarity standard deviation: 0.06
# Asynchronous global intra theme similarity average: 0.43
# Asynchronous global intra theme similarity standard deviation: 0.05

# %%
inter_global_avg_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']!=global_average_df['anno2_theme'])] 

print(f"Synchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global inter theme similarity average: 0.40
# Synchronous global inter theme similarity standard deviation: 0.04
# Asynchronous global inter theme similarity average: 0.39
# Asynchronous global inter theme similarity standard deviation: 0.04
