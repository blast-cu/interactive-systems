# %% [markdown]
# ## Imports

# %%
import sqlite3
import glob
import time
import itertools 

import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.notebook import tqdm
# Out:
# /var/folders/zk/q1b5d0j13nd6dhkv7g8yk2hc0000gn/T/ipykernel_80229/1025221560.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# _____

# %% [markdown]
# ## 1. Data Ingestion
#
# Read the data from the database.

# %%
annotated_dbs = glob.glob(f'./dataset/pacheco_system/*.db')

print("Found the following dbs : " , annotated_dbs)

synchronous_annotators = ['group_1' , 'group_2'] 
asynchronous_annotators = ['async_1' , 'async_2' , 'async_3'] 
annotators = synchronous_annotators + asynchronous_annotators
annotator2df = {}

for db_path in  annotated_dbs : 

    con = sqlite3.connect(db_path)
    tweet_df = pd.read_sql_query('SELECT * FROM tweet;' , con) 
    theme_df = pd.read_sql_query('SELECT * FROM theme;' , con) 
    theme_df = theme_df.rename(columns={'id' : 'theme_id'})
    merged_df = tweet_df.merge(theme_df , how='left' , on='theme_id')

    for key in annotators : 
        if key in db_path : 
            annotator2df[key] = merged_df
# Out:
# Found the following dbs :  ['./dataset/pacheco_system/async_1.db', './dataset/pacheco_system/group_1.db', './dataset/pacheco_system/async_3.db', './dataset/pacheco_system/group_2.db', './dataset/pacheco_system/async_2.db']

# %% [markdown]
# ### 1.a. Random Sampling rows for manual annotations
#
# Pull 200 samples from both synchronous and asynchronous groups to manually review label quality. Pulling from top 25th percentile is done later.

# %%
synchronous_random_samples = []
asynchronous_random_samples = []

for annotator , df in annotator2df.items(): 
    if annotator in synchronous_annotators: 
        synchronous_random_samples.append(df.sample(n=100))
    if annotator in asynchronous_annotators: 
        asynchronous_random_samples.append(df.sample(n=67))

res_df = pd.concat(synchronous_random_samples)
async_df = pd.concat(asynchronous_random_samples)

res_df = res_df[['text' , 'name']].sample(frac=1)
async_df = async_df[['text' , 'name']].sample(frac=1)

res_df.to_csv('./dataset/generated_samples/pacheco_sync_sample_all.csv' , index=False, sep='\t')
async_df.to_csv('./dataset/generated_samples/pacheco_async_sample_all.csv' , index=False, sep='\t')

# %% [markdown]
# _____

# %% [markdown]
# ## 2. Jaccard Similarity
#
# Jaccard similarity for two themes is calculated by the union of their documents divided by the intersection of their documents.

# %%
results = []

for anno_1 , anno_2 in itertools.permutations(annotators , 2): 
    anno_1_themes = annotator2df[anno_1]['name'].unique()
    anno_2_themes = annotator2df[anno_2]['name'].unique()
    for anno_1_theme , anno_2_theme in itertools.product(anno_1_themes , anno_2_themes): 
        result = {'anno_1' : anno_1 , 
                  'anno_2' : anno_2 , 
                  'anno_1_theme' : anno_1_theme ,
                  'anno_2_theme' : anno_2_theme}
        anno_1_tweet_ids = set(annotator2df[anno_1][annotator2df[anno_1]['name']==anno_1_theme]['tweet_id'])
        anno_2_tweet_ids = set(annotator2df[anno_2][annotator2df[anno_2]['name']==anno_2_theme]['tweet_id'])
        intersection = anno_1_tweet_ids.intersection(anno_2_tweet_ids)
        union = anno_1_tweet_ids.union(anno_2_tweet_ids)
        jaccard_sim = len(intersection) / len(union)
        result['jaccard_sim'] = jaccard_sim
        results.append(result)

jaccard_df = pd.DataFrame(results)

# %% [markdown]
# ### 2.a. Getting max jaccard similarity for synchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(synchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(synchronous_annotators))]

for anno_1_theme in filtered_df['anno_1_theme'].unique(): 
    if ('kmeans' not in anno_1_theme.lower()) and  ('Unknown' not in anno_1_theme.strip()):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Asynchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
print(res_df.count())
# Out:
# Asynchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.36
# Standard Deviation of Jaccard Similarity: 0.20
# anno_1          16
# anno_2          16
# anno_1_theme    16
# anno_2_theme    16
# jaccard_sim     16
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                          anno_1_theme  \
# 0   group_1  group_2                           VaxSymptoms
# 1   group_1  group_2                       GovGoodPolicies
# 2   group_1  group_2                    VaxAppointmentInfo
# 3   group_1  group_2                       VaxApprovalInfo
# 4   group_1  group_2                         VaxDoesntWork
# 5   group_1  group_2                  UnjustifiedFearOfVax
# 6   group_1  group_2                            IGotTheVax
# 7   group_1  group_2                        GovBadPolicies
# 8   group_1  group_2                    VaxLessensSymptoms
# 9   group_2  group_1                       PostVaxSymptoms
# 10  group_2  group_1         ReasonsForUSLaggingOnVaccines
# 11  group_2  group_1  VaxDistributionIssueDueToLocalPolicy
# 12  group_2  group_1                   VaxAvailabilityInfo
# 13  group_2  group_1                        #IGotMyVaccine
# 14  group_2  group_1               VaxDoesMoreHarmThanGood
# 15  group_2  group_1                           FDAapproval
#
#                             anno_2_theme  jaccard_sim
# 0                        PostVaxSymptoms     0.650243
# 1   VaxDistributionIssueDueToLocalPolicy     0.188921
# 2                    VaxAvailabilityInfo     0.568418
# 3                            FDAapproval     0.381999
# 4                VaxDoesMoreHarmThanGood     0.155343
# 5                VaxDoesMoreHarmThanGood     0.058224
# 6                         #IGotMyVaccine     0.487331
# 7          ReasonsForUSLaggingOnVaccines     0.208917
# 8                     VaxLessensSymptoms     0.417115
# 9                            VaxSymptoms     0.650243
# 10                        GovBadPolicies     0.208917
# 11                       GovGoodPolicies     0.188921
# 12                    VaxAppointmentInfo     0.568418
# 13                            IGotTheVax     0.487331
# 14                         VaxDoesntWork     0.155343
# 15                       VaxApprovalInfo     0.381999

# %% [markdown]
# ### 2.b. Getting max jaccard similarity for asynchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(asynchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(asynchronous_annotators))]
for anno_1_theme in filtered_df['anno_1_theme'].unique():
    if ('kmeans' not in anno_1_theme.lower()) and  ('Unknown' not in anno_1_theme.strip()):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Synchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
# Out:
# Synchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.30
# Standard Deviation of Jaccard Similarity: 0.23

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                                       anno_1_theme  \
# 0   async_1  async_3              Receiving_first_dose_of_covid_vaccine
# 1   async_1  async_3                      Criticising_political_figures
# 2   async_1  async_3              Promoting_covid_related_news_articles
# 3   async_1  async_3             Vaccine_accessibility_and_distribution
# 4   async_1  async_3  Information_about_covid_vaccine_availability_a...
# 5   async_1  async_3        Encouraging_people_to_get_the_covid_vaccine
# 6   async_1  async_2  The_vaccine_does_not_work_because_you_can_stil...
# 7   async_1  async_3                  Skepticism_over_the_covid_vaccine
# 8   async_1  async_3                Experiences_of_vaccine_side_effects
# 9   async_1  async_3              Praising_frontline_healthcare_workers
# 10  async_1  async_3  Saying_that_you_can_still_get_covid_if_you_hav...
# 11  async_1  async_2                      Receiving_second_vaccine_dose
# 12  async_1  async_3                    Encouraging_getting_the_vaccine
# 13  async_1  async_2                          Criticising_The_President
# 14  async_1  async_3                      FDA_Approval_of_covid_vaccine
# 15  async_1  async_3  Providing_resources_to_those_who_are_not_invol...
# 16  async_1  async_3                     Praising_Government_Leadership
# 17  async_1  async_2                         Against_covid_disbelievers
# 18  async_1  async_2      Stating_that_the_vaccine_does_not_cause_covid
# 19  async_2  async_1                                      GotVaccinated
# 20  async_2  async_1                                     AntiRepublican
# 21  async_2  async_3                                  WhereToGetVaccine
# 22  async_2  async_1                                 AdvocateForVaccine
# 23  async_2  async_3                               VaccineSymptomReport
# 24  async_2  async_3                              VaccineEfficacyDenial
# 25  async_2  async_3                                     VaccineRefusal
# 26  async_2  async_1                                       VaccineKills
# 27  async_2  async_1                                       AntiDemocrat
# 28  async_2  async_1                                         BlameFauci
# 29  async_3  async_1                    ReceivedfirstdoseofCOVIDvaccine
# 30  async_3  async_1                        RepublicansdownplayingCOVID
# 31  async_3  async_1                            FDAapprovesCOVIDvaccine
# 32  async_3  async_1                             GettingtheCOVIDvaccine
# 33  async_3  async_1              NewsarticlesaboutCOVIDvaccineprogress
# 34  async_3  async_1                                    ProCOVIDvaccine
# 35  async_3  async_1                                     Mentionsamayor
# 36  async_3  async_1             NewsagenciesreportingontheCovidvaccine
# 37  async_3  async_1                                   AntiCovidVaccine
# 38  async_3  async_1                           Covidvaccineaftereffects
# 39  async_3  async_1                                GetyourCOVIDvaccine
# 40  async_3  async_2           BidenadministrationenforcingCOVIDvaccine
# 41  async_3  async_1           COVIDvaccineonlyreducestheeffectsofCOVID
# 42  async_3  async_1                                  HealthcareWorkers
# 43  async_3  async_1                                          AntiBiden
# 44  async_3  async_1                                NegativeviewonTrump
# 45  async_3  async_1               RepublicansresponsibleforCOVIDdeaths
# 46  async_3  async_1                                     Israeloutbreak
#
#                                          anno_2_theme  jaccard_sim
# 0                     ReceivedfirstdoseofCOVIDvaccine     0.621659
# 1                         RepublicansdownplayingCOVID     0.272509
# 2               NewsarticlesaboutCOVIDvaccineprogress     0.290772
# 3                                     ProCOVIDvaccine     0.221095
# 4                              GettingtheCOVIDvaccine     0.716777
# 5                                 GetyourCOVIDvaccine     0.395771
# 6                               VaccineEfficacyDenial     0.059856
# 7                                    AntiCovidVaccine     0.433612
# 8                            Covidvaccineaftereffects     0.775336
# 9                                     ProCOVIDvaccine     0.093837
# 10           COVIDvaccineonlyreducestheeffectsofCOVID     0.438716
# 11                                      GotVaccinated     0.102082
# 12                                    ProCOVIDvaccine     0.102475
# 13                                       AntiDemocrat     0.289952
# 14                            FDAapprovesCOVIDvaccine     0.435839
# 15             NewsagenciesreportingontheCovidvaccine     0.112360
# 16                                NegativeviewonTrump     0.073574
# 17                                       VaccineKills     0.044013
# 18                              VaccineEfficacyDenial     0.037685
# 19              Receiving_first_dose_of_covid_vaccine     0.516870
# 20                      Criticising_political_figures     0.216493
# 21                             GettingtheCOVIDvaccine     0.531565
# 22                  Skepticism_over_the_covid_vaccine     0.175160
# 23                           Covidvaccineaftereffects     0.749687
# 24                                   AntiCovidVaccine     0.334170
# 25                                   AntiCovidVaccine     0.102778
# 26                      Criticising_political_figures     0.049209
# 27                          Criticising_The_President     0.289952
# 28  Providing_resources_to_those_who_are_not_invol...     0.055917
# 29              Receiving_first_dose_of_covid_vaccine     0.621659
# 30                      Criticising_political_figures     0.272509
# 31                      FDA_Approval_of_covid_vaccine     0.435839
# 32  Information_about_covid_vaccine_availability_a...     0.716777
# 33              Promoting_covid_related_news_articles     0.290772
# 34             Vaccine_accessibility_and_distribution     0.221095
# 35                     Praising_Government_Leadership     0.057198
# 36  Providing_resources_to_those_who_are_not_invol...     0.112360
# 37                  Skepticism_over_the_covid_vaccine     0.433612
# 38                Experiences_of_vaccine_side_effects     0.775336
# 39        Encouraging_people_to_get_the_covid_vaccine     0.395771
# 40                                       AntiDemocrat     0.269930
# 41  Saying_that_you_can_still_get_covid_if_you_hav...     0.438716
# 42  Providing_resources_to_those_who_are_not_invol...     0.072141
# 43                          Criticising_The_President     0.186286
# 44  Providing_resources_to_those_who_are_not_invol...     0.090773
# 45  Providing_resources_to_those_who_are_not_invol...     0.076613
# 46  Providing_resources_to_those_who_are_not_invol...     0.035264

# %% [markdown]
# ______

# %% [markdown]
# ## 3. Centroid Cosine Similarity

# %% [markdown]
# ### 3.a. Loading SBERT Vectors

# %%
sbert_vectors = np.load('./dataset/sbert.npy')

# %% [markdown]
# ### 3.b. Calculating centroids for sync + async experiments

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if 'kmeans' not in theme.lower(): 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim 
            results.append(result)

# %% [markdown]
# ### 3.c. Calculating synchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results: 
        for anno_2_result in anno_2_results:
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Synchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Synchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.99
# Standard Deviation of Centroid Cosine Similarity: 0.01
# anno_1          17
# anno_2          17
# anno_1_theme    17
# anno_2_theme    17
# cosine_sim      17
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                          anno_1_theme  \
# 0   group_1  group_2                           VaxSymptoms
# 1   group_1  group_2                       GovGoodPolicies
# 2   group_1  group_2                    VaxAppointmentInfo
# 3   group_1  group_2                       VaxApprovalInfo
# 4   group_1  group_2                         VaxDoesntWork
# 5   group_1  group_2                  UnjustifiedFearOfVax
# 6   group_1  group_2                            IGotTheVax
# 7   group_1  group_2                        GovBadPolicies
# 8   group_1  group_2                    VaxLessensSymptoms
# 9   group_2  group_1                       PostVaxSymptoms
# 10  group_2  group_1         ReasonsForUSLaggingOnVaccines
# 11  group_2  group_1  VaxDistributionIssueDueToLocalPolicy
# 12  group_2  group_1                   VaxAvailabilityInfo
# 13  group_2  group_1                        #IGotMyVaccine
# 14  group_2  group_1               VaxDoesMoreHarmThanGood
# 15  group_2  group_1                    VaxLessensSymptoms
# 16  group_2  group_1                           FDAapproval
#
#                             anno_2_theme  cosine_sim
# 0                        PostVaxSymptoms  0.99895835
# 1   VaxDistributionIssueDueToLocalPolicy  0.96528137
# 2                    VaxAvailabilityInfo     0.99799
# 3                            FDAapproval   0.9812027
# 4                VaxDoesMoreHarmThanGood  0.97540057
# 5                VaxDoesMoreHarmThanGood   0.9572651
# 6                         #IGotMyVaccine    0.995323
# 7          ReasonsForUSLaggingOnVaccines  0.98667836
# 8                     VaxLessensSymptoms  0.99518436
# 9                            VaxSymptoms  0.99895835
# 10                        GovBadPolicies  0.98667836
# 11                       GovGoodPolicies  0.96528137
# 12                    VaxAppointmentInfo     0.99799
# 13                            IGotTheVax    0.995323
# 14                         VaxDoesntWork  0.97540057
# 15                    VaxLessensSymptoms  0.99518436
# 16                       VaxApprovalInfo   0.9812027

# %% [markdown]
# ### 3.d. Calculating asynchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results : 
        for anno_2_result in anno_2_results :
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Asynchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Asynchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.95
# Standard Deviation of Centroid Cosine Similarity: 0.08
# anno_1          94
# anno_2          94
# anno_1_theme    94
# anno_2_theme    94
# cosine_sim      94
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                                       anno_1_theme  \
# 0   async_1  async_2              Receiving_first_dose_of_covid_vaccine
# 1   async_1  async_2                      Criticising_political_figures
# 2   async_1  async_2              Promoting_covid_related_news_articles
# 3   async_1  async_2             Vaccine_accessibility_and_distribution
# 4   async_1  async_2  Information_about_covid_vaccine_availability_a...
# ..      ...      ...                                                ...
# 89  async_3  async_2                                  HealthcareWorkers
# 90  async_3  async_2                                          AntiBiden
# 91  async_3  async_2                                NegativeviewonTrump
# 92  async_3  async_2               RepublicansresponsibleforCOVIDdeaths
# 93  async_3  async_2                                     Israeloutbreak
#
#           anno_2_theme  cosine_sim
# 0        GotVaccinated    0.993977
# 1       AntiRepublican  0.98237693
# 2   AdvocateForVaccine  0.95669174
# 3    WhereToGetVaccine   0.9413523
# 4    WhereToGetVaccine    0.982838
# ..                 ...         ...
# 89          BlameFauci  0.71381944
# 90        AntiDemocrat   0.9753418
# 91          BlameFauci  0.72613084
# 92          BlameFauci   0.7145619
# 93          BlameFauci   0.7879021
#
# [94 rows x 5 columns]

# %% [markdown]
# ____

# %% [markdown]
# ## 4. Group Average Cosine Similarity

# %%
results = {}
annotators = []

for annotator, df in annotator2df.items():
  results[annotator] = {}
  annotators.append(annotator)
  for i , theme in enumerate(df['name'].unique()):
      if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()):
          ids = df[df['name'] == theme]['tweet_id'].tolist()
          theme_vectors = sbert_vectors[ids]
          results[annotator][theme] = theme_vectors

# %% [markdown]
# ### 4.a. Calculating Group Average Similarities

# %%
global_average_sims = []

for (anno1 , anno2) in tqdm(itertools.combinations_with_replacement(annotators, 2)):
  anno1_themes = results[anno1]
  anno2_themes = results[anno2]
  for anno1_theme, anno1_theme_vectors in anno1_themes.items():
    for anno2_theme, anno2_theme_vectors in anno2_themes.items():
      s_time = time.time()
      cosine_sims = cosine_similarity(anno1_theme_vectors , anno2_theme_vectors)
      average_sim = np.average(cosine_sims)
      std_deviation = np.std(cosine_sims)
      global_average_sims.append({'anno1' : anno1 ,
                                  'anno2' : anno2 ,
                                  'anno1_theme' : anno1_theme ,
                                  'anno2_theme' : anno2_theme ,
                                  'average_sim' : average_sim ,
                                  'std_deviation' : std_deviation
                                  })
# Out:
# 0it [00:00, ?it/s]

# %%
global_average_sims
# Out:
# [{'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.5871065,
#   'std_deviation': 0.13545135},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.3610672,
#   'std_deviation': 0.11115836},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.43287352,
#   'std_deviation': 0.13017313},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.41418797,
#   'std_deviation': 0.113564715},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.42118356,
#   'std_deviation': 0.10620071},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.47635671,
#   'std_deviation': 0.11685051},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.41615757,
#   'std_deviation': 0.100157484},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4177419,
#   'std_deviation': 0.10679404},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.49172726,
#   'std_deviation': 0.1260922},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.49347445,
#   'std_deviation': 0.120219894},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.42202678,
#   'std_deviation': 0.103315376},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.5396286,
#   'std_deviation': 0.12577325},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.41451025,
#   'std_deviation': 0.10392483},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.34575963,
#   'std_deviation': 0.11346001},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.44779992,
#   'std_deviation': 0.115948424},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.13990666,
#   'std_deviation': 0.08794294},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.35460335,
#   'std_deviation': 0.15555467},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.35778382,
#   'std_deviation': 0.14314634},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.42240223,
#   'std_deviation': 0.10065354},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.3610671,
#   'std_deviation': 0.11115828},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.4528441,
#   'std_deviation': 0.11127985},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.40847388,
#   'std_deviation': 0.12297144},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.40047422,
#   'std_deviation': 0.1088309},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.32077852,
#   'std_deviation': 0.10217751},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.405543,
#   'std_deviation': 0.11564611},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.4020977,
#   'std_deviation': 0.112538666},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4107724,
#   'std_deviation': 0.11156376},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.330346,
#   'std_deviation': 0.105191834},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.40669826,
#   'std_deviation': 0.108511135},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.38848427,
#   'std_deviation': 0.11711494},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.37219465,
#   'std_deviation': 0.11126618},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.44533014,
#   'std_deviation': 0.11037697},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.4330716,
#   'std_deviation': 0.11660615},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.41033688,
#   'std_deviation': 0.11226251},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.19710326,
#   'std_deviation': 0.09497336},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.3532177,
#   'std_deviation': 0.13148114},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.38144097,
#   'std_deviation': 0.15902492},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Criticising_political_figures',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.3999542,
#   'std_deviation': 0.11189628},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.43287462,
#   'std_deviation': 0.13017337},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.40847436,
#   'std_deviation': 0.12297157},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.45366368,
#   'std_deviation': 0.14573547},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.41948313,
#   'std_deviation': 0.122947134},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.36728725,
#   'std_deviation': 0.1205633},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.4374796,
#   'std_deviation': 0.13135333},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.42604157,
#   'std_deviation': 0.13231124},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4214579,
#   'std_deviation': 0.12963288},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.38430488,
#   'std_deviation': 0.1261995},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.45605242,
#   'std_deviation': 0.12607364},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.41878492,
#   'std_deviation': 0.13820767},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.425327,
#   'std_deviation': 0.1303481},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.4407217,
#   'std_deviation': 0.13017602},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.3941223,
#   'std_deviation': 0.1290023},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.46488747,
#   'std_deviation': 0.13759018},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.19481862,
#   'std_deviation': 0.08477512},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.36352786,
#   'std_deviation': 0.15022011},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.37510994,
#   'std_deviation': 0.15971808},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Promoting_covid_related_news_articles',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.41761518,
#   'std_deviation': 0.13642947},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.41418704,
#   'std_deviation': 0.11356464},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.400474,
#   'std_deviation': 0.10883088},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.41948307,
#   'std_deviation': 0.12294697},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.45702612,
#   'std_deviation': 0.11460921},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.4135355,
#   'std_deviation': 0.11335942},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.42669544,
#   'std_deviation': 0.1122886},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.40614963,
#   'std_deviation': 0.10663871},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4055931,
#   'std_deviation': 0.10459384},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.3465508,
#   'std_deviation': 0.101563096},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.466368,
#   'std_deviation': 0.11300184},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.39195478,
#   'std_deviation': 0.10599128},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.40916902,
#   'std_deviation': 0.111781456},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.43220088,
#   'std_deviation': 0.10547927},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.3894368,
#   'std_deviation': 0.117272794},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.42999327,
#   'std_deviation': 0.11203382},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.16946906,
#   'std_deviation': 0.090755574},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.39604378,
#   'std_deviation': 0.15625128},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.35902408,
#   'std_deviation': 0.1540885},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine_accessibility_and_distribution',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.4112091,
#   'std_deviation': 0.10701572},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.42118388,
#   'std_deviation': 0.106200516},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.320777,
#   'std_deviation': 0.10217748},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.36728767,
#   'std_deviation': 0.120563425},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.4135357,
#   'std_deviation': 0.1133595},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.49372798,
#   'std_deviation': 0.1218462},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.4034674,
#   'std_deviation': 0.109507546},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.38106787,
#   'std_deviation': 0.0976992},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.37621492,
#   'std_deviation': 0.09967877},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.35381994,
#   'std_deviation': 0.10038999},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.4403871,
#   'std_deviation': 0.1120644},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.38968918,
#   'std_deviation': 0.10021169},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.41218746,
#   'std_deviation': 0.10883068},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.3738972,
#   'std_deviation': 0.09872805},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.30909166,
#   'std_deviation': 0.1101511},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.39235914,
#   'std_deviation': 0.107902326},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.09228716,
#   'std_deviation': 0.08331623},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.34251836,
#   'std_deviation': 0.1715314},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.30341285,
#   'std_deviation': 0.14635435},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.41046566,
#   'std_deviation': 0.103719905},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.47635627,
#   'std_deviation': 0.116850525},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.405543,
#   'std_deviation': 0.11564621},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.4374793,
#   'std_deviation': 0.13135336},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.42669696,
#   'std_deviation': 0.11228854},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.40346774,
#   'std_deviation': 0.10950751},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.49631837,
#   'std_deviation': 0.12211583},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.44781446,
#   'std_deviation': 0.110363126},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4519778,
#   'std_deviation': 0.11121035},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.43265113,
#   'std_deviation': 0.11615918},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.46302134,
#   'std_deviation': 0.11388674},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.45865375,
#   'std_deviation': 0.116463415},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.46966073,
#   'std_deviation': 0.11770023},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.46642742,
#   'std_deviation': 0.113852516},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.38287643,
#   'std_deviation': 0.11918247},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.4434829,
#   'std_deviation': 0.11349433},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.15232766,
#   'std_deviation': 0.082884416},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.35824466,
#   'std_deviation': 0.15078902},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.39615098,
#   'std_deviation': 0.16226637},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.4652077,
#   'std_deviation': 0.114721656},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.41615734,
#   'std_deviation': 0.10015756},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.40209752,
#   'std_deviation': 0.11253864},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.42604196,
#   'std_deviation': 0.13231131},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.40614983,
#   'std_deviation': 0.10663873},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.3810677,
#   'std_deviation': 0.09769921},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.44781446,
#   'std_deviation': 0.11036308},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.51368654,
#   'std_deviation': 0.11996444},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.48053914,
#   'std_deviation': 0.105601795},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.42374343,
#   'std_deviation': 0.10873564},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.42214662,
#   'std_deviation': 0.10349503},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.5214974,
#   'std_deviation': 0.110211514},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.40862548,
#   'std_deviation': 0.10832366},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.49424008,
#   'std_deviation': 0.106485106},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.38217402,
#   'std_deviation': 0.12162937},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.45742163,
#   'std_deviation': 0.1075491},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.10427206,
#   'std_deviation': 0.08199067},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.328993,
#   'std_deviation': 0.15579294},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.39440745,
#   'std_deviation': 0.18838026},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.5336368,
#   'std_deviation': 0.112960964},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.4177419,
#   'std_deviation': 0.106794104},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.41077343,
#   'std_deviation': 0.11156373},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.4214591,
#   'std_deviation': 0.12963304},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.40559205,
#   'std_deviation': 0.1045938},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.37621468,
#   'std_deviation': 0.099678814},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.45197743,
#   'std_deviation': 0.111210264},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.48053914,
#   'std_deviation': 0.10560188},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.47408405,
#   'std_deviation': 0.1047147},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.41475558,
#   'std_deviation': 0.11215719},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.42231786,
#   'std_deviation': 0.10382037},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.4932153,
#   'std_deviation': 0.10978242},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.41493425,
#   'std_deviation': 0.110944934},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.4858241,
#   'std_deviation': 0.10414632},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.3892718,
#   'std_deviation': 0.1199781},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.4466839,
#   'std_deviation': 0.10705475},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.114783384,
#   'std_deviation': 0.08485461},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.33060387,
#   'std_deviation': 0.1506416},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.39656278,
#   'std_deviation': 0.18258777},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.51022124,
#   'std_deviation': 0.109753735},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.491728,
#   'std_deviation': 0.12609234},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.33034614,
#   'std_deviation': 0.10519174},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.38430497,
#   'std_deviation': 0.12619957},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.3465504,
#   'std_deviation': 0.10156315},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.3538197,
#   'std_deviation': 0.10039003},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.43265218,
#   'std_deviation': 0.116159126},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.42374364,
#   'std_deviation': 0.108735666},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.41475573,
#   'std_deviation': 0.11215719},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.536227,
#   'std_deviation': 0.13695799},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.39757088,
#   'std_deviation': 0.109001875},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.4401279,
#   'std_deviation': 0.11178347},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.46709204,
#   'std_deviation': 0.12031504},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.3996552,
#   'std_deviation': 0.10489816},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.309393,
#   'std_deviation': 0.10571496},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.40864438,
#   'std_deviation': 0.10986612},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.09645784,
#   'std_deviation': 0.07344563},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.28389904,
#   'std_deviation': 0.13923319},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.33943295,
#   'std_deviation': 0.15362921},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.43207023,
#   'std_deviation': 0.1140634},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.49347478,
#   'std_deviation': 0.12021984},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.4066983,
#   'std_deviation': 0.108511165},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.45605275,
#   'std_deviation': 0.1260736},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.46636787,
#   'std_deviation': 0.11300184},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.44038737,
#   'std_deviation': 0.11206438},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.46302098,
#   'std_deviation': 0.1138868},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.4221468,
#   'std_deviation': 0.10349501},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.42231745,
#   'std_deviation': 0.103820324},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.39757106,
#   'std_deviation': 0.109001815},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.52882594,
#   'std_deviation': 0.11883347},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.41694194,
#   'std_deviation': 0.106619865},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.47373357,
#   'std_deviation': 0.11645493},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.44399688,
#   'std_deviation': 0.105769515},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.39124328,
#   'std_deviation': 0.11518741},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.4612949,
#   'std_deviation': 0.11339911},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.1834158,
#   'std_deviation': 0.08440264},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.40609178,
#   'std_deviation': 0.15785179},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.37660033,
#   'std_deviation': 0.14662023},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.42827278,
#   'std_deviation': 0.105715245},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.42202607,
#   'std_deviation': 0.10331537},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Criticising_political_figures',
#   'average_sim': 0.3884839,
#   'std_deviation': 0.11711496},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Promoting_covid_related_news_articles',
#   'average_sim': 0.4187842,
#   'std_deviation': 0.13820773},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Vaccine_accessibility_and_distribution',
#   'average_sim': 0.39195505,
#   'std_deviation': 0.10599127},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Information_about_covid_vaccine_availability_and_appointments',
#   'average_sim': 0.38968924,
#   'std_deviation': 0.10021168},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Encouraging_people_to_get_the_covid_vaccine',
#   'average_sim': 0.45865342,
#   'std_deviation': 0.11646345},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'average_sim': 0.52149713,
#   'std_deviation': 0.11021152},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Skepticism_over_the_covid_vaccine',
#   'average_sim': 0.4932151,
#   'std_deviation': 0.10978242},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Experiences_of_vaccine_side_effects',
#   'average_sim': 0.44012824,
#   'std_deviation': 0.11178348},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Praising_frontline_healthcare_workers',
#   'average_sim': 0.41694197,
#   'std_deviation': 0.10661987},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'average_sim': 0.5666788,
#   'std_deviation': 0.10430329},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Receiving_second_vaccine_dose',
#   'average_sim': 0.41338623,
#   'std_deviation': 0.11054028},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Encouraging_getting_the_vaccine',
#   'average_sim': 0.49652448,
#   'std_deviation': 0.109713234},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Criticising_The_President',
#   'average_sim': 0.3653638,
#   'std_deviation': 0.12424932},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'FDA_Approval_of_covid_vaccine',
#   'average_sim': 0.44672832,
#   'std_deviation': 0.110534385},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'average_sim': 0.07716099,
#   'std_deviation': 0.080103844},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Praising_Government_Leadership',
#   'average_sim': 0.31323075,
#   'std_deviation': 0.16004582},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Against_covid_disbelievers',
#   'average_sim': 0.3901444,
#   'std_deviation': 0.19298077},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'Stating_that_the_vaccine_does_not_cause_covid',
#   'average_sim': 0.5745178,
#   'std_deviation': 0.108872384},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'Receiving_first_dose_of_covid_vaccine',
#   'average_sim': 0.53962857,
#   'std_deviation': 0.12577325},
# ...
#   'average_sim': 0.42497388,
#   'std_deviation': 0.10742921},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.3998718,
#   'std_deviation': 0.14188924},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.41259435,
#   'std_deviation': 0.11406685},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.38313082,
#   'std_deviation': 0.09338691},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.43990445,
#   'std_deviation': 0.08686016},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.4736337,
#   'std_deviation': 0.13114795},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.5194226,
#   'std_deviation': 0.11377767},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'The_vaccine_does_not_work_because_you_can_still_get_covid',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.45759457,
#   'std_deviation': 0.10632137},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.4246167,
#   'std_deviation': 0.10972076},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.40252158,
#   'std_deviation': 0.13829404},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.40939456,
#   'std_deviation': 0.1125234},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.37720206,
#   'std_deviation': 0.09661312},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.44247842,
#   'std_deviation': 0.09833545},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.47189534,
#   'std_deviation': 0.12729885},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.49127588,
#   'std_deviation': 0.1109325},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Skepticism_over_the_covid_vaccine',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.44675848,
#   'std_deviation': 0.107195914},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.4830976,
#   'std_deviation': 0.1360422},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.33164865,
#   'std_deviation': 0.12798132},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.35579616,
#   'std_deviation': 0.10909158},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.36417478,
#   'std_deviation': 0.10254568},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.5275784,
#   'std_deviation': 0.11679805},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.41280907,
#   'std_deviation': 0.12595037},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.42992312,
#   'std_deviation': 0.11285364},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Experiences_of_vaccine_side_effects',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.43436056,
#   'std_deviation': 0.11939205},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.411724,
#   'std_deviation': 0.10877717},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.40147328,
#   'std_deviation': 0.12545905},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.4679528,
#   'std_deviation': 0.11926069},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.440397,
#   'std_deviation': 0.11208824},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.509044,
#   'std_deviation': 0.11198129},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.43034193,
#   'std_deviation': 0.11634477},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.40996963,
#   'std_deviation': 0.10604089},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Praising_frontline_healthcare_workers',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.46678567,
#   'std_deviation': 0.118418075},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.4338422,
#   'std_deviation': 0.11201678},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.38967204,
#   'std_deviation': 0.14982274},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.404158,
#   'std_deviation': 0.11547947},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.39391017,
#   'std_deviation': 0.0961001},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.45138848,
#   'std_deviation': 0.09018468},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.4848855,
#   'std_deviation': 0.13982242},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.5606509,
#   'std_deviation': 0.109656535},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Saying_that_you_can_still_get_covid_if_you_have_the_vaccine',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.45412233,
#   'std_deviation': 0.10856922},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.46487275,
#   'std_deviation': 0.12041449},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.3673241,
#   'std_deviation': 0.12873104},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.41495976,
#   'std_deviation': 0.117925406},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.42457205,
#   'std_deviation': 0.1112212},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.57244,
#   'std_deviation': 0.11879431},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.42496008,
#   'std_deviation': 0.12247211},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.4031699,
#   'std_deviation': 0.10893659},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Receiving_second_vaccine_dose',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.45884788,
#   'std_deviation': 0.13020408},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.41722763,
#   'std_deviation': 0.107213944},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.4318184,
#   'std_deviation': 0.13775855},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.4330002,
#   'std_deviation': 0.1147425},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.37107337,
#   'std_deviation': 0.094721094},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.43388477,
#   'std_deviation': 0.09317829},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.4940581,
#   'std_deviation': 0.12757863},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.49719456,
#   'std_deviation': 0.10961942},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Encouraging_getting_the_vaccine',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.4526062,
#   'std_deviation': 0.10724518},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.3299983,
#   'std_deviation': 0.11140647},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.41094223,
#   'std_deviation': 0.13295437},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.38467062,
#   'std_deviation': 0.12580849},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.308648,
#   'std_deviation': 0.1087171},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.35892898,
#   'std_deviation': 0.10987202},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.3973435,
#   'std_deviation': 0.12781212},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.36774313,
#   'std_deviation': 0.12434421},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Criticising_The_President',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.3901391,
#   'std_deviation': 0.122681834},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.41043085,
#   'std_deviation': 0.107174374},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.4112829,
#   'std_deviation': 0.132065},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.4407207,
#   'std_deviation': 0.12251882},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.3926374,
#   'std_deviation': 0.10552182},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.4693283,
#   'std_deviation': 0.106234066},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.4371628,
#   'std_deviation': 0.1193136},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'VaxLessensSymptoms',
#   'average_sim': 0.4428779,
#   'std_deviation': 0.11070012},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'FDA_Approval_of_covid_vaccine',
#   'anno2_theme': 'FDAapproval',
#   'average_sim': 0.51723504,
#   'std_deviation': 0.12953706},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': 'PostVaxSymptoms',
#   'average_sim': 0.09952793,
#   'std_deviation': 0.07491803},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': 'ReasonsForUSLaggingOnVaccines',
#   'average_sim': 0.18616022,
#   'std_deviation': 0.09684784},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': 'VaxDistributionIssueDueToLocalPolicy',
#   'average_sim': 0.16417019,
#   'std_deviation': 0.09493683},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': 'VaxAvailabilityInfo',
#   'average_sim': 0.083171524,
#   'std_deviation': 0.08270006},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': '#IGotMyVaccine',
#   'average_sim': 0.13440573,
#   'std_deviation': 0.08574017},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Providing_resources_to_those_who_are_not_involved_in_the_covid_debate',
#   'anno2_theme': 'VaxDoesMoreHarmThanGood',
#   'average_sim': 0.1323432,
#   'std_deviation': 0.087624446},
#  ...]

# %%
global_average_df = pd.DataFrame(global_average_sims)

# %% [markdown]
# ### 4.b. Calculating Synchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Synchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Synchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.52
# Standard Deviation of Group Cosine Similarity: 0.08
# anno1            9
# anno2            9
# anno1_theme      9
# anno2_theme      9
# average_sim      9
# std_deviation    9
# dtype: int64

# %% [markdown]
# ### 4.c. Calculating Asynchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Asynchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Asynchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.45
# Standard Deviation of Group Cosine Similarity: 0.10
# anno1            56
# anno2            56
# anno1_theme      56
# anno2_theme      56
# average_sim      56
# std_deviation    56
# dtype: int64

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Getting top 25th percentile of closest vectors to each centroid

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()): 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            result['tweets'] = df[df['name'] == theme]['text'].tolist()

            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim.squeeze() 
            results.append(result)

# %%
top_25_results = {'top_25_tweets':[],
                  'top_25_vectors' : [], 
                  'theme' : [], 
                  'annotator' : []}

for result in results: 

    m = np.percentile(result['cosine_sim'] , 75)
    top_25_indices = np.where(result['cosine_sim']>m)
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results['top_25_tweets'].extend(top_25_tweets)
    top_25_results['top_25_vectors'].extend(top_25_vectors )
    top_25_results['theme'].extend([theme]*top_25_tweets.shape[0])
    top_25_results['annotator'].extend([annotator]*top_25_tweets.shape[0])


top_25_df = pd.DataFrame(top_25_results, columns=['theme' , 'annotator' , 'top_25_tweets'])

# %% [markdown]
# ### 4.a. Random Sampling rows for manual annotations

# %%
sync_top_25 = top_25_df[top_25_df['annotator'].isin(synchronous_annotators)].sample(n=200)[['theme' , 'top_25_tweets']]
async_top_25 = top_25_df[top_25_df['annotator'].isin(asynchronous_annotators)].sample(n=200)[['theme' , 'top_25_tweets']]

sync_top_25.to_csv('./dataset/generated_samples/pacheco_sync_sample_top25.csv' , index=False, sep='\t')
async_top_25.to_csv('./dataset/generated_samples/pacheco_async_sample_top25.csv' , index=False, sep='\t')

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Calculating Intra- and Inter-cluster Similarity

# %%
top_25_results = {}

for result in results: 

    top_25_results[result['theme']] = {}

    m = np.percentile(result['cosine_sim'] , 75)
    top_25_indices = np.where(result['cosine_sim']>m)
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results[theme]['top_25_tweets'] = (top_25_tweets)
    top_25_results[theme]['top_25_vectors'] = (top_25_vectors )
    top_25_results[theme]['annotator'] = (annotator)

# %% [markdown]
# ### 5.a. Calculating similarities for top 25th percentile clusters

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_25_average_sims = []

for anno_1_theme , anno1_top_25 in tqdm(top_25_results.items()): 
    for anno_2_theme , anno2_top_25 in top_25_results.items(): 

        anno1_top_25_vectors = anno1_top_25['top_25_vectors']
        anno2_top_25_vectors = anno2_top_25['top_25_vectors']

        cosine_sims = cosine_similarity(anno1_top_25_vectors , anno2_top_25_vectors)
        average_sim = np.average(cosine_sims)
        std_deviation = np.std(cosine_sims)

        top_25_average_sims.append({'anno_1' : anno1_top_25['annotator'] , 
                                   'anno_2' : anno2_top_25['annotator'], 
                                   'anno_1_theme' : anno_1_theme,
                                   'anno_2_theme' : anno_2_theme,
                                   'average_sim' : average_sim , 
                                   'std_dev_sim' : std_deviation})
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]

# %%
top_25_average_df = pd.DataFrame(top_25_average_sims)
top_25_average_df
# Out:
#        anno_1   anno_2                           anno_1_theme  \
# 0     async_1  async_1  Receiving_first_dose_of_covid_vaccine
# 1     async_1  async_1  Receiving_first_dose_of_covid_vaccine
# 2     async_1  async_1  Receiving_first_dose_of_covid_vaccine
# 3     async_1  async_1  Receiving_first_dose_of_covid_vaccine
# 4     async_1  async_1  Receiving_first_dose_of_covid_vaccine
# ...       ...      ...                                    ...
# 3964  async_2  async_2                             BlameFauci
# 3965  async_2  async_2                             BlameFauci
# 3966  async_2  async_2                             BlameFauci
# 3967  async_2  async_2                             BlameFauci
# 3968  async_2  async_2                             BlameFauci
#
#                                            anno_2_theme  average_sim  \
# 0                 Receiving_first_dose_of_covid_vaccine     0.782726
# 1                         Criticising_political_figures     0.435086
# 2                 Promoting_covid_related_news_articles     0.564126
# 3                Vaccine_accessibility_and_distribution     0.508773
# 4     Information_about_covid_vaccine_availability_a...     0.491469
# ...                                                 ...          ...
# 3964                              VaccineEfficacyDenial     0.484998
# 3965                                     VaccineRefusal     0.475791
# 3966                                       VaccineKills     0.469780
# 3967                                       AntiDemocrat     0.511179
# 3968                                         BlameFauci     0.611577
#
#       std_dev_sim
# 0        0.056958
# 1        0.076976
# 2        0.083993
# 3        0.074464
# 4        0.071028
# ...           ...
# 3964     0.094103
# 3965     0.086528
# 3966     0.077280
# 3967     0.070955
# 3968     0.095039
#
# [3969 rows x 6 columns]

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']==top_25_average_df['anno_2_theme'])]

# %% [markdown]
# ### 5.b. Intra- and Inter-theme similarities for top 25th percentile subsets in synchronous and asynchronous experiments

# %%
print(f"Synchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% intra theme similarity average: 0.70
# Synchronous top 25% intra theme similarity standard deviation: 0.09
# Asynchronous top 25% intra theme similarity average: 0.64
# Asynchronous top 25% intra theme similarity standard deviation: 0.09

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']!=top_25_average_df['anno_2_theme'])]

# %%
print(f"Synchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% inter theme similarity average: 0.52
# Synchronous top 25% inter theme similarity standard deviation: 0.07
# Asynchronous top 25% inter theme similarity average: 0.46
# Asynchronous top 25% inter theme similarity standard deviation: 0.13

# %% [markdown]
# ### 5.c. Intra- and Inter-theme similarities for whole set in synchronous and asynchronous experiments

# %%
global_average_df = pd.DataFrame(global_average_sims)

intra_global_average_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']==global_average_df['anno2_theme'])] 


print(f"Synchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global intra theme similarity average: 0.51
# Synchronous global intra theme similarity standard deviation: 0.08
# Asynchronous global intra theme similarity average: 0.45
# Asynchronous global intra theme similarity standard deviation: 0.10

# %%
inter_global_avg_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']!=global_average_df['anno2_theme'])] 

print(f"Synchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global inter theme similarity average: 0.42
# Synchronous global inter theme similarity standard deviation: 0.05
# Asynchronous global inter theme similarity average: 0.34
# Asynchronous global inter theme similarity standard deviation: 0.11
