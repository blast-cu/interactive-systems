# %% [markdown]
# ## Imports

# %%
import sqlite3
import glob
import time
import itertools 

import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.notebook import tqdm
# Out:
# /var/folders/zk/q1b5d0j13nd6dhkv7g8yk2hc0000gn/T/ipykernel_19293/1025221560.py:7: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# _____

# %% [markdown]
# ## 1. Data Ingestion
#
# Read the data from the database.

# %%
annotated_dbs = glob.glob(f'./dataset/fang_system/*.json')

print("Found the following dbs : " , annotated_dbs)

synchronous_annotators = ['group_1' , 'group_2'] 
asynchronous_annotators = ['async_1' , 'async_2' , 'async_3'] 
annotators = synchronous_annotators + asynchronous_annotators
annotator2df = {}

for db_path in  annotated_dbs : 
    merged_df = pd.read_json(db_path)

    for key in annotators : 
        if key in db_path : 
            annotator2df[key] = merged_df
# Out:
# Found the following dbs :  ['./dataset/fang_system/async_1.json', './dataset/fang_system/group_1.json', './dataset/fang_system/group_2.json', './dataset/fang_system/async_2.json', './dataset/fang_system/async_3.json']

# %% [markdown]
# ### 1.a. Random Sampling rows for manual annotations
#
# Pull 200 samples from both synchronous and asynchronous groups to manually review label quality. Pulling from top 25th percentile is done later.

# %%
synchronous_random_samples = []
asynchronous_random_samples = []

for annotator , df in annotator2df.items(): 
    if annotator in synchronous_annotators: 
        synchronous_random_samples.append(df.sample(n=100))
    if annotator in asynchronous_annotators: 
        asynchronous_random_samples.append(df.sample(n=67))

res_df = pd.concat(synchronous_random_samples)
async_df = pd.concat(asynchronous_random_samples)

res_df = res_df[['text' , 'name']].sample(frac=1)
async_df = async_df[['text' , 'name']].sample(frac=1)

res_df.to_csv('./dataset/generated_samples/fang_sync_sample_all.csv' , index=False, sep='\t')
async_df.to_csv('./dataset/generated_samples/fang_async_sample_all.csv' , index=False, sep='\t')

# %% [markdown]
# _____

# %% [markdown]
# ## 2. Jaccard Similarity
#
# Jaccard similarity for two themes is calculated by the union of their documents divided by the intersection of their documents.

# %%
results = []

for anno_1 , anno_2 in itertools.permutations(annotators , 2): 
    anno_1_themes = annotator2df[anno_1]['name'].unique()
    anno_2_themes = annotator2df[anno_2]['name'].unique()
    for anno_1_theme , anno_2_theme in itertools.product(anno_1_themes , anno_2_themes): 
        result = {'anno_1' : anno_1 , 
                  'anno_2' : anno_2 , 
                  'anno_1_theme' : anno_1_theme ,
                  'anno_2_theme' : anno_2_theme}
        anno_1_tweet_ids = set(annotator2df[anno_1][annotator2df[anno_1]['name']==anno_1_theme]['tweet_id'])
        anno_2_tweet_ids = set(annotator2df[anno_2][annotator2df[anno_2]['name']==anno_2_theme]['tweet_id'])
        intersection = anno_1_tweet_ids.intersection(anno_2_tweet_ids)
        union = anno_1_tweet_ids.union(anno_2_tweet_ids)
        jaccard_sim = len(intersection) / len(union)
        result['jaccard_sim'] = jaccard_sim
        results.append(result)

jaccard_df = pd.DataFrame(results)

# %% [markdown]
# ### 2.a. Getting max jaccard similarity for synchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(synchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(synchronous_annotators))]

for anno_1_theme in filtered_df['anno_1_theme'].unique(): 
    if ('kmeans' not in anno_1_theme.lower()) and  ('Unknown' not in anno_1_theme.strip()):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Asynchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
print(res_df.count())
# Out:
# Asynchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.56
# Standard Deviation of Jaccard Similarity: 0.23
# anno_1          31
# anno_2          31
# anno_1_theme    31
# anno_2_theme    31
# jaccard_sim     31
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                                       anno_1_theme  \
# 0   group_1  group_2  trump supporters saying biden is wrongfully ta...
# 1   group_1  group_2                            side effects of vaccine
# 2   group_1  group_2                     announcing vaccine eligibility
# 3   group_1  group_2         wholesome reactions to getting the vaccine
# 4   group_1  group_2                              inefficacy of vaccine
# 5   group_1  group_2                corelation between trauma and covid
# 6   group_1  group_2         halting vaccination due to adverse effects
# 7   group_1  group_2                                   proof of vaccine
# 8   group_1  group_2                           appeal to get vaccinated
# 9   group_1  group_2                               covid related deaths
# 10  group_1  group_2                 advertising for covid related jobs
# 11  group_1  group_2                     freebies with proof of vaccine
# 12  group_1  group_2                concerns about  effects of vaccines
# 13  group_1  group_2  disproportionate impact and equitable recover ...
# 14  group_1  group_2     political conspiracy / nicki minaj controversy
# 15  group_1  group_2                               vaccine appointments
# 16  group_2  group_1      criticism of governments' response to vaccine
# 17  group_2  group_1                    family covid vaccine experience
# 18  group_2  group_1                    immediate personal side effects
# 19  group_2  group_1                          state vaccine eligibility
# 20  group_2  group_1                      non-covid vaccine comparision
# 21  group_2  group_1        institutional adverse childhood experiences
# 22  group_2  group_1                              vaccine certification
# 23  group_2  group_1                   anti-vaccine conspiracy outcomes
# 24  group_2  group_1                                              Error
# 25  group_2  group_1                                    pharmacy hiring
# 26  group_2  group_1                               FDA vaccine approval
# 27  group_2  group_1                             long term side effects
# 28  group_2  group_1                           community vaccine equity
# 29  group_2  group_1                  vaccine side effects/ Nicki Minaj
# 30  group_2  group_1                                  covid appointment
#
#                                          anno_2_theme  jaccard_sim
# 0       criticism of governments' response to vaccine     0.366044
# 1                     immediate personal side effects     0.830508
# 2                           state vaccine eligibility     0.712030
# 3                     family covid vaccine experience     0.680976
# 4                       non-covid vaccine comparision     0.670501
# 5         institutional adverse childhood experiences     0.499351
# 6                                               Error     0.424947
# 7                               vaccine certification     0.700150
# 8                    anti-vaccine conspiracy outcomes     0.004349
# 9                    anti-vaccine conspiracy outcomes     0.567097
# 10                                    pharmacy hiring     0.615385
# 11                              vaccine certification     0.013889
# 12                             long term side effects     0.500000
# 13                           community vaccine equity     0.580460
# 14                  vaccine side effects/ Nicki Minaj     0.567568
# 15                                  covid appointment     0.925676
# 16  trump supporters saying biden is wrongfully ta...     0.366044
# 17         wholesome reactions to getting the vaccine     0.680976
# 18                            side effects of vaccine     0.830508
# 19                     announcing vaccine eligibility     0.712030
# 20                              inefficacy of vaccine     0.670501
# 21                corelation between trauma and covid     0.499351
# 22                                   proof of vaccine     0.700150
# 23                               covid related deaths     0.567097
# 24         halting vaccination due to adverse effects     0.424947
# 25                 advertising for covid related jobs     0.615385
# 26                concerns about  effects of vaccines     0.047619
# 27                concerns about  effects of vaccines     0.500000
# 28  disproportionate impact and equitable recover ...     0.580460
# 29     political conspiracy / nicki minaj controversy     0.567568
# 30                               vaccine appointments     0.925676

# %% [markdown]
# ### 2.b. Getting max jaccard similarity for asynchronous experiments

# %%
max_jacc_sims = []
filtered_df = jaccard_df[(jaccard_df['anno_1'].isin(asynchronous_annotators)) 
                         &(jaccard_df['anno_2'].isin(asynchronous_annotators))]
for anno_1_theme in filtered_df['anno_1_theme'].unique():
    if ('kmeans' not in anno_1_theme.lower()) and  ('Unknown' not in anno_1_theme.strip()):
        theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) & 
                                            ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
        max_jacc_sims.append(theme_filtered_df.loc[(theme_filtered_df['jaccard_sim'].idxmax())].to_dict())
res_df = pd.DataFrame(max_jacc_sims)

print("Synchronous Jaccard Similarity")
print(f"Average Max Jaccard Similarity: {res_df['jaccard_sim'].mean():.2f}")
print(f"Standard Deviation of Jaccard Similarity: {res_df['jaccard_sim'].std():.2f}")
# Out:
# Synchronous Jaccard Similarity
# Average Max Jaccard Similarity: 0.30
# Standard Deviation of Jaccard Similarity: 0.17

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                                       anno_1_theme  \
# 0   async_1  async_3                  Pro Trump and against Biden/Obama
# 1   async_1  async_2          Dispelling misinformation regarding death
# 2   async_1  async_2                               Vaccine availability
# 3   async_1  async_2                              2nd dose side effects
# 4   async_1  async_3                Comparisons to other virus vaccines
# 5   async_1  async_3                           Anger over mask mandates
# 6   async_1  async_3                       Reminders of the 2nd vaccine
# 7   async_1  async_3                              Origin of the vaccine
# 8   async_1  async_2                     Discussing vaccines in schools
# 9   async_1  async_3                       Positive outcomes of vaccine
# 10  async_1  async_3     Concerns regarding Johnson and Johnson vaccine
# 11  async_1  async_3                                   CVS job openings
# 12  async_1  async_2     Information aimed towards minority communities
# 13  async_1  async_2                               Against anti-vaxxers
# 14  async_1  async_3                                  Calling out liars
# 15  async_1  async_2                    Free food for vaccinated people
# 16  async_1  async_2                              Vaccine card mandates
# 17  async_1  async_3                                 Vaccine hesistancy
# 18  async_1  async_3                           Vaccine appointment info
# 19  async_2  async_1                                 VaccineRolloutNews
# 20  async_2  async_1                                          AntiTrump
# 21  async_2  async_3                                 VaccineSideEffects
# 22  async_2  async_1                                 VaccineTestScience
# 23  async_2  async_3                         HopefulPeopleGetVaccinated
# 24  async_2  async_1                                  WhereToGetVaccine
# 25  async_2  async_3                                  FDANews&Discourse
# 26  async_2  async_3                                VaccinePassportNews
# 27  async_2  async_3                                           FakeNews
# 28  async_2  async_1                                    VaccineAdvocacy
# 29  async_2  async_3                                     AntiRepublican
# 30  async_2  async_1                                       AntiDemocrat
# 31  async_2  async_3                                       PandemicNews
# 32  async_2  async_3                                   VaccineHesitancy
# 33  async_2  async_1                                POCVaccineAwareness
# 34  async_2  async_1                             FightingDisinformation
# 35  async_2  async_3                                   VaccineChildRisk
# 36  async_2  async_3                                VaccineProblemsNews
# 37  async_3  async_1                 Anti-Biden and Pro-Trump Sentiment
# 38  async_3  async_2  Comparing the COVID Vaccine to other Deadly Di...
# 39  async_3  async_1  Anger towards COVID Deniers/COVID Deniers Pass...
# 40  async_3  async_2  Immediate After-Effects from COVID Vaccine(sor...
# 41  async_3  async_2         Family Members Receiving the COVID Vaccine
# 42  async_3  async_2                        Vaccine Eligibility Updates
# 43  async_3  async_2        Proof of Vaccination(vaccine card/passport)
# 44  async_3  async_1  Adverse Childhood Experience's being casued by...
# 45  async_3  async_2                  COVID Vaccine causing Blood Clots
# 46  async_3  async_1                Become a Pharmacy Technician Alerts
# 47  async_3  async_1                          COVID FDA Approval Status
# 48  async_3  async_1        Anger Towards Republicans Lying about COVID
# 49  async_3  async_2  Giving Info about COVID and the Vaccine to Min...
# 50  async_3  async_1              Walgreens Vaccine Appointment Updates
#
#                                          anno_2_theme  jaccard_sim
# 0                  Anti-Biden and Pro-Trump Sentiment     0.211271
# 1                                  VaccineTestScience     0.204602
# 2                                  VaccineRolloutNews     0.557431
# 3                                  VaccineSideEffects     0.626506
# 4   Anger towards COVID Deniers/COVID Deniers Pass...     0.351531
# 5         Proof of Vaccination(vaccine card/passport)     0.292924
# 6          Family Members Receiving the COVID Vaccine     0.282486
# 7   Adverse Childhood Experience's being casued by...     0.308894
# 8                                 VaccinePassportNews     0.055118
# 9          Family Members Receiving the COVID Vaccine     0.256587
# 10                  COVID Vaccine causing Blood Clots     0.200900
# 11                Become a Pharmacy Technician Alerts     0.312977
# 12                                POCVaccineAwareness     0.481229
# 13                                 VaccineTestScience     0.064725
# 14        Anger Towards Republicans Lying about COVID     0.339207
# 15                                VaccinePassportNews     0.024514
# 16                                VaccinePassportNews     0.049003
# 17                          COVID FDA Approval Status     0.304878
# 18              Walgreens Vaccine Appointment Updates     0.656593
# 19                               Vaccine availability     0.557431
# 20                Comparisons to other virus vaccines     0.266703
# 21  Immediate After-Effects from COVID Vaccine(sor...     0.634461
# 22          Dispelling misinformation regarding death     0.204602
# 23         Family Members Receiving the COVID Vaccine     0.293734
# 24                           Vaccine appointment info     0.272876
# 25                          COVID FDA Approval Status     0.152406
# 26        Proof of Vaccination(vaccine card/passport)     0.437857
# 27  Comparing the COVID Vaccine to other Deadly Di...     0.187344
# 28          Dispelling misinformation regarding death     0.050671
# 29                 Anti-Biden and Pro-Trump Sentiment     0.107334
# 30                  Pro Trump and against Biden/Obama     0.162149
# 31                  COVID Vaccine causing Blood Clots     0.085038
# 32  Adverse Childhood Experience's being casued by...     0.238710
# 33     Information aimed towards minority communities     0.481229
# 34                                  Calling out liars     0.083333
# 35  Adverse Childhood Experience's being casued by...     0.075610
# 36                  COVID Vaccine causing Blood Clots     0.255014
# 37                  Pro Trump and against Biden/Obama     0.211271
# 38                                           FakeNews     0.187344
# 39                Comparisons to other virus vaccines     0.351531
# 40                                 VaccineSideEffects     0.634461
# 41                         HopefulPeopleGetVaccinated     0.293734
# 42                                 VaccineRolloutNews     0.247156
# 43                                VaccinePassportNews     0.437857
# 44                              Origin of the vaccine     0.308894
# 45                                VaccineProblemsNews     0.255014
# 46                                   CVS job openings     0.312977
# 47                                 Vaccine hesistancy     0.304878
# 48                                  Calling out liars     0.339207
# 49                                POCVaccineAwareness     0.434066
# 50                           Vaccine appointment info     0.656593

# %% [markdown]
# ______

# %% [markdown]
# ## 3. Centroid Cosine Similarity

# %% [markdown]
# ### 3.a. Loading SBERT Vectors

# %%
sbert_vectors = np.load('./dataset/sbert.npy')

# %% [markdown]
# ### 3.b. Calculating centroids for sync + async experiments

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if 'kmeans' not in theme.lower(): 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim 
            results.append(result)

# %% [markdown]
# ### 3.c. Calculating synchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results: 
        for anno_2_result in anno_2_results:
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Synchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Synchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.98
# Standard Deviation of Centroid Cosine Similarity: 0.05
# anno_1          31
# anno_2          31
# anno_1_theme    31
# anno_2_theme    31
# cosine_sim      31
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#      anno_1   anno_2                                       anno_1_theme  \
# 0   group_1  group_2  trump supporters saying biden is wrongfully ta...
# 1   group_1  group_2                            side effects of vaccine
# 2   group_1  group_2                     announcing vaccine eligibility
# 3   group_1  group_2         wholesome reactions to getting the vaccine
# 4   group_1  group_2                              inefficacy of vaccine
# 5   group_1  group_2                corelation between trauma and covid
# 6   group_1  group_2         halting vaccination due to adverse effects
# 7   group_1  group_2                                   proof of vaccine
# 8   group_1  group_2                           appeal to get vaccinated
# 9   group_1  group_2                               covid related deaths
# 10  group_1  group_2                 advertising for covid related jobs
# 11  group_1  group_2                     freebies with proof of vaccine
# 12  group_1  group_2                concerns about  effects of vaccines
# 13  group_1  group_2  disproportionate impact and equitable recover ...
# 14  group_1  group_2     political conspiracy / nicki minaj controversy
# 15  group_1  group_2                               vaccine appointments
# 16  group_2  group_1      criticism of governments' response to vaccine
# 17  group_2  group_1                    family covid vaccine experience
# 18  group_2  group_1                    immediate personal side effects
# 19  group_2  group_1                          state vaccine eligibility
# 20  group_2  group_1                      non-covid vaccine comparision
# 21  group_2  group_1        institutional adverse childhood experiences
# 22  group_2  group_1                              vaccine certification
# 23  group_2  group_1                   anti-vaccine conspiracy outcomes
# 24  group_2  group_1                                              Error
# 25  group_2  group_1                                    pharmacy hiring
# 26  group_2  group_1                               FDA vaccine approval
# 27  group_2  group_1                             long term side effects
# 28  group_2  group_1                           community vaccine equity
# 29  group_2  group_1                  vaccine side effects/ Nicki Minaj
# 30  group_2  group_1                                  covid appointment
#
#                                          anno_2_theme  cosine_sim
# 0       criticism of governments' response to vaccine   0.9865336
# 1                     immediate personal side effects  0.99987227
# 2                           state vaccine eligibility   0.9990996
# 3                     family covid vaccine experience  0.99775624
# 4                       non-covid vaccine comparision   0.9993112
# 5         institutional adverse childhood experiences  0.99786264
# 6                                               Error   0.9898355
# 7                               vaccine certification  0.99753714
# 8                    anti-vaccine conspiracy outcomes  0.93612516
# 9                    anti-vaccine conspiracy outcomes  0.99549055
# 10                                    pharmacy hiring   0.9974661
# 11                              vaccine certification   0.7239828
# 12                             long term side effects  0.98781127
# 13                           community vaccine equity  0.99810773
# 14                  vaccine side effects/ Nicki Minaj  0.99181354
# 15                                  covid appointment   0.9998576
# 16  trump supporters saying biden is wrongfully ta...   0.9865336
# 17         wholesome reactions to getting the vaccine  0.99775624
# 18                            side effects of vaccine  0.99987227
# 19                     announcing vaccine eligibility   0.9990996
# 20                              inefficacy of vaccine   0.9993112
# 21                corelation between trauma and covid  0.99786264
# 22                                   proof of vaccine  0.99753714
# 23                               covid related deaths  0.99549055
# 24         halting vaccination due to adverse effects   0.9898355
# 25                 advertising for covid related jobs   0.9974661
# 26         halting vaccination due to adverse effects  0.91652894
# 27                concerns about  effects of vaccines  0.98781127
# 28  disproportionate impact and equitable recover ...  0.99810773
# 29     political conspiracy / nicki minaj controversy  0.99181354
# 30                               vaccine appointments   0.9998576

# %% [markdown]
# ### 3.d. Calculating asynchronous centroid cosine similarity

# %%
cosine_sim_results = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    anno_1_results = [r for r in results if r['annotator']==anno_1]
    anno_2_results = [r for r in results if r['annotator']==anno_2]
    for anno_1_result in anno_1_results : 
        for anno_2_result in anno_2_results :
            if ('kmeans' not in anno_1_result['theme'].lower()) and  ('kmeans' not in anno_2_result['theme'].lower()): 
                cosine_sim = cosine_similarity(anno_1_result['theme_centroid'] , anno_2_result['theme_centroid'])
                cosine_sim_result = {'anno_1' : anno_1 , 
                                    'anno_2' : anno_2 , 
                                    'anno_1_theme' : anno_1_result['theme'] , 
                                    'anno_2_theme' : anno_2_result['theme'] , 
                                    'cosine_sim' : cosine_sim.squeeze()}
                cosine_sim_results.append(cosine_sim_result)
                
cosine_sim_df = pd.DataFrame(cosine_sim_results)

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = cosine_sim_df[(cosine_sim_df['anno_1']== anno_1) & (cosine_sim_df['anno_2']== anno_2)]
    for anno_1_theme in filtered_df['anno_1_theme'].unique():
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno_1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno_2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['cosine_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Asynchronous Centroid Cosine Similarity")
print(f"Average Max Centroid Cosine Similarity: {res_df['cosine_sim'].mean():.2f}")
print(f"Standard Deviation of Centroid Cosine Similarity: {res_df['cosine_sim'].std():.2f}")
print(res_df.count())
# Out:
# Asynchronous Centroid Cosine Similarity
# Average Max Centroid Cosine Similarity: 0.96
# Standard Deviation of Centroid Cosine Similarity: 0.05
# anno_1          102
# anno_2          102
# anno_1_theme    102
# anno_2_theme    102
# cosine_sim      102
# dtype: int64

# %%
# To view individual similarities
res_df
# Out:
#       anno_1   anno_2                                       anno_1_theme  \
# 0    async_1  async_2                  Pro Trump and against Biden/Obama
# 1    async_1  async_2          Dispelling misinformation regarding death
# 2    async_1  async_2                               Vaccine availability
# 3    async_1  async_2                              2nd dose side effects
# 4    async_1  async_2                Comparisons to other virus vaccines
# ..       ...      ...                                                ...
# 97   async_3  async_2                Become a Pharmacy Technician Alerts
# 98   async_3  async_2                          COVID FDA Approval Status
# 99   async_3  async_2        Anger Towards Republicans Lying about COVID
# 100  async_3  async_2  Giving Info about COVID and the Vaccine to Min...
# 101  async_3  async_2              Walgreens Vaccine Appointment Updates
#
#             anno_2_theme  cosine_sim
# 0           AntiDemocrat   0.9638065
# 1     VaccineTestScience   0.9884341
# 2     VaccineRolloutNews   0.9930198
# 3     VaccineSideEffects  0.99872065
# 4              AntiTrump  0.98132145
# ..                   ...         ...
# 97    VaccineRolloutNews   0.9550743
# 98     FDANews&Discourse  0.99019384
# 99             AntiTrump  0.90378076
# 100  POCVaccineAwareness   0.9945967
# 101    WhereToGetVaccine  0.96960485
#
# [102 rows x 5 columns]

# %% [markdown]
# ____

# %% [markdown]
# ## 4. Group Average Cosine Similarity

# %%
results = {}
annotators = []

for annotator, df in annotator2df.items():
  results[annotator] = {}
  annotators.append(annotator)
  for i , theme in enumerate(df['name'].unique()):
      if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()):
          ids = df[df['name'] == theme]['tweet_id'].tolist()
          theme_vectors = sbert_vectors[ids]
          results[annotator][theme] = theme_vectors

# %% [markdown]
# ### 4.a. Calculating Group Average Similarities

# %%
global_average_sims = []
total_combos = len(list(itertools.combinations_with_replacement(annotators, 2)))

for ctr , (anno1 , anno2) in enumerate(itertools.combinations_with_replacement(annotators, 2)):
  anno1_themes = results[anno1]
  anno2_themes = results[anno2]
  for anno1_theme, anno1_theme_vectors in anno1_themes.items():
    for anno2_theme, anno2_theme_vectors in anno2_themes.items():
      s_time = time.time()
      cosine_sims = cosine_similarity(anno1_theme_vectors , anno2_theme_vectors)
      average_sim = np.average(cosine_sims)
      std_deviation = np.std(cosine_sims)
      global_average_sims.append({'anno1' : anno1 ,
                                  'anno2' : anno2 ,
                                  'anno1_theme' : anno1_theme ,
                                  'anno2_theme' : anno2_theme ,
                                  'average_sim' : average_sim ,
                                  'std_deviation' : std_deviation
                                  })
      print(f"Completed {ctr+1}/{total_combos} combinations.\nTotal time to calc : {time.time() - s_time} seconds. \n{global_average_sims[-1]}\n--------\n")
      # save for reference since this calculation runs much slower than for pacheco data
      pd.DataFrame(global_average_sims).to_csv('./dataset/fang_system/std_dev_aggregated_sims.csv', index=False)
# Out:
# Completed 1/15 combinations.
# Total time to calc : 1.6969120502471924 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.38501024, 'std_deviation': 0.1547931}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.9480109214782715 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.3898052, 'std_deviation': 0.14515024}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.361253023147583 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.37891957, 'std_deviation': 0.14455523}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.11123299598693848 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.3363732, 'std_deviation': 0.14243443}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 3.5685081481933594 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.39129966, 'std_deviation': 0.1457191}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.5482618808746338 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.38434565, 'std_deviation': 0.1346536}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.38866114616394043 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.4026332, 'std_deviation': 0.15365437}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.09455704689025879 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.3695131, 'std_deviation': 0.14634246}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05312609672546387 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.3885489, 'std_deviation': 0.137784}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.0486218929290771 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.37368557, 'std_deviation': 0.1477749}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08950018882751465 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.42247492, 'std_deviation': 0.14317353}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08740973472595215 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'CVS job openings', 'average_sim': 0.38257772, 'std_deviation': 0.14186633}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08522701263427734 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.4047892, 'std_deviation': 0.13275492}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.1738898754119873 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.39683333, 'std_deviation': 0.13732965}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05341315269470215 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Calling out liars', 'average_sim': 0.37181616, 'std_deviation': 0.1346197}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.031410932540893555 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.35570058, 'std_deviation': 0.11467385}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03867626190185547 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.3428388, 'std_deviation': 0.12922953}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.036337852478027344 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.39207807, 'std_deviation': 0.14812693}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.058818817138671875 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Pro Trump and against Biden/Obama', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.33529457, 'std_deviation': 0.13245264}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.0134787559509277 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.38980663, 'std_deviation': 0.14515035}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.6591610908508301 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.47539994, 'std_deviation': 0.12187069}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.7722811698913574 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.40216896, 'std_deviation': 0.11407772}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07827305793762207 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.41694498, 'std_deviation': 0.11490212}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.9996798038482666 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.44650927, 'std_deviation': 0.124650225}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.259871244430542 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.41672346, 'std_deviation': 0.11214667}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.2605319023132324 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.43299904, 'std_deviation': 0.10789266}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07959508895874023 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.45822018, 'std_deviation': 0.11857446}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.036975860595703125 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.42565686, 'std_deviation': 0.10924858}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.6872282028198242 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.4106254, 'std_deviation': 0.12531546}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07844805717468262 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.47023204, 'std_deviation': 0.10385456}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08257198333740234 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'CVS job openings', 'average_sim': 0.3922389, 'std_deviation': 0.10996948}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07804226875305176 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.4299438, 'std_deviation': 0.11053873}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.15752077102661133 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.4438186, 'std_deviation': 0.12016304}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.059339046478271484 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Calling out liars', 'average_sim': 0.39215276, 'std_deviation': 0.12693447}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.02471613883972168 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.3451126, 'std_deviation': 0.08374293}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.023797035217285156 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.37024868, 'std_deviation': 0.09906219}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.021173954010009766 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.4455813, 'std_deviation': 0.11335425}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.04877209663391113 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Dispelling misinformation regarding death', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.3730554, 'std_deviation': 0.081730254}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.0027952194213867 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.37891874, 'std_deviation': 0.14455523}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.7569208145141602 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.40216964, 'std_deviation': 0.114077896}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.6945180892944336 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.4639409, 'std_deviation': 0.12192754}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08162307739257812 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.37096512, 'std_deviation': 0.1092507}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 2.0683090686798096 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.39693412, 'std_deviation': 0.11954626}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.24169397354125977 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.3977574, 'std_deviation': 0.111303836}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.28066086769104004 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.45629987, 'std_deviation': 0.120908394}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.09761714935302734 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.38428915, 'std_deviation': 0.11186808}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.055403709411621094 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.43405366, 'std_deviation': 0.11401732}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.707334041595459 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.40870735, 'std_deviation': 0.12572786}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.06385111808776855 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.44425347, 'std_deviation': 0.109307565}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.069580078125 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'CVS job openings', 'average_sim': 0.46542674, 'std_deviation': 0.1177203}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07623410224914551 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.432888, 'std_deviation': 0.11467023}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.13472199440002441 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.39035293, 'std_deviation': 0.118388645}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.04828214645385742 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Calling out liars', 'average_sim': 0.35515475, 'std_deviation': 0.12520638}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.024776935577392578 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.4016851, 'std_deviation': 0.08959309}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.035283803939819336 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.39228043, 'std_deviation': 0.09829791}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.030185937881469727 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.3953222, 'std_deviation': 0.11450304}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.047595977783203125 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Vaccine availability', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.4737113, 'std_deviation': 0.12463807}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.09491109848022461 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.3363733, 'std_deviation': 0.14243436}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0729210376739502 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.41694513, 'std_deviation': 0.11490207}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0730290412902832 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.37096515, 'std_deviation': 0.10925071}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.01147317886352539 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.64759964, 'std_deviation': 0.1139642}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.14425921440124512 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.40508303, 'std_deviation': 0.1233618}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.026983022689819336 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.33633068, 'std_deviation': 0.09955824}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03993701934814453 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.5001619, 'std_deviation': 0.118069895}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.021934032440185547 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.41363743, 'std_deviation': 0.10534762}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.00618433952331543 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.34404346, 'std_deviation': 0.08774015}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.06954288482666016 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.43038416, 'std_deviation': 0.13067634}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.006070137023925781 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.4246004, 'std_deviation': 0.091741644}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0069539546966552734 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'CVS job openings', 'average_sim': 0.3655481, 'std_deviation': 0.104249775}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0059969425201416016 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.34731266, 'std_deviation': 0.10055406}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.015835046768188477 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.36853683, 'std_deviation': 0.10949332}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.005053997039794922 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Calling out liars', 'average_sim': 0.31432924, 'std_deviation': 0.111860886}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0052280426025390625 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.31557122, 'std_deviation': 0.072336294}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0037147998809814453 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.32423574, 'std_deviation': 0.0839163}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0071828365325927734 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.38402423, 'std_deviation': 0.09835339}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.005992889404296875 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': '2nd dose side effects', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.35528582, 'std_deviation': 0.060164005}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 2.882835865020752 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.39130214, 'std_deviation': 0.14571951}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.9778029918670654 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.44650862, 'std_deviation': 0.12465013}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.7484819889068604 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.39693445, 'std_deviation': 0.119546264}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.14190173149108887 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.40508354, 'std_deviation': 0.123361744}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 4.11090087890625 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.44625092, 'std_deviation': 0.128377}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.5934007167816162 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.41600585, 'std_deviation': 0.115175985}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.5147578716278076 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.43174526, 'std_deviation': 0.120694645}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.1638200283050537 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.43550637, 'std_deviation': 0.1233141}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.06792020797729492 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.41569158, 'std_deviation': 0.1134818}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 1.249377965927124 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.41251984, 'std_deviation': 0.12984687}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.10489606857299805 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.4466512, 'std_deviation': 0.108511485}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.15157032012939453 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'CVS job openings', 'average_sim': 0.39074135, 'std_deviation': 0.115883335}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.11566495895385742 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.42031536, 'std_deviation': 0.112503685}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.23597311973571777 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.44030696, 'std_deviation': 0.122057855}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07405591011047363 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Calling out liars', 'average_sim': 0.38614136, 'std_deviation': 0.12448876}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.041626691818237305 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.36615753, 'std_deviation': 0.09182869}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05242109298706055 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.37994868, 'std_deviation': 0.10687692}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.04690885543823242 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.43192813, 'std_deviation': 0.12040993}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07552504539489746 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Comparisons to other virus vaccines', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.36326253, 'std_deviation': 0.091716506}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.30315709114074707 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.38434508, 'std_deviation': 0.13465361}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.2831001281738281 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.4167234, 'std_deviation': 0.11214662}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.23710179328918457 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.3977577, 'std_deviation': 0.11130393}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.031150102615356445 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.3363308, 'std_deviation': 0.09955825}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.49525904655456543 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.41600573, 'std_deviation': 0.11517596}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05381584167480469 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.4598717, 'std_deviation': 0.11578519}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08123588562011719 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.3946458, 'std_deviation': 0.106089026}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.020760774612426758 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.395085, 'std_deviation': 0.112975076}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.012398242950439453 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.45241532, 'std_deviation': 0.11028345}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.18217778205871582 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.3833476, 'std_deviation': 0.11803612}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.020127058029174805 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.42379522, 'std_deviation': 0.099856764}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03657698631286621 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'CVS job openings', 'average_sim': 0.39086366, 'std_deviation': 0.10867556}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.022103071212768555 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.41652155, 'std_deviation': 0.10283946}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03800511360168457 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.4232371, 'std_deviation': 0.111384004}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.010833263397216797 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Calling out liars', 'average_sim': 0.37605786, 'std_deviation': 0.11614486}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.007776021957397461 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.36378366, 'std_deviation': 0.0850274}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.013615131378173828 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.38984942, 'std_deviation': 0.0991505}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.008723020553588867 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.40430412, 'std_deviation': 0.10715101}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.017768383026123047 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Anger over mask mandates', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.34795895, 'std_deviation': 0.0868498}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.3095109462738037 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.40263373, 'std_deviation': 0.15365437}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.2552499771118164 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.43299973, 'std_deviation': 0.10789269}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.3141779899597168 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.45629948, 'std_deviation': 0.12090835}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.027289152145385742 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.5001616, 'std_deviation': 0.118069865}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.4926588535308838 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.43174562, 'std_deviation': 0.12069463}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08177423477172852 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.39464614, 'std_deviation': 0.106089026}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.07126188278198242 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.5648231, 'std_deviation': 0.13067836}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.02454233169555664 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.42133185, 'std_deviation': 0.1025531}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.010947942733764648 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.41570196, 'std_deviation': 0.10741709}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.2286219596862793 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.47438118, 'std_deviation': 0.13291909}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.024374008178710938 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.4761472, 'std_deviation': 0.10308998}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03543496131896973 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'CVS job openings', 'average_sim': 0.47220644, 'std_deviation': 0.1227936}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.025582075119018555 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.43718624, 'std_deviation': 0.111106545}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.041436195373535156 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.41131592, 'std_deviation': 0.113755986}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.01338815689086914 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Calling out liars', 'average_sim': 0.36000326, 'std_deviation': 0.11858574}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.006891012191772461 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.4087625, 'std_deviation': 0.08656166}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.011710166931152344 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.37830433, 'std_deviation': 0.093207724}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.009181976318359375 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.42605135, 'std_deviation': 0.116308376}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.013477087020874023 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Reminders of the 2nd vaccine', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.42647555, 'std_deviation': 0.07515451}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08173608779907227 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.3695132, 'std_deviation': 0.14634249}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.08006000518798828 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.45822054, 'std_deviation': 0.11857443}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.06503915786743164 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.38428938, 'std_deviation': 0.11186812}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.006681203842163086 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.41363743, 'std_deviation': 0.105347626}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.13184595108032227 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.4355066, 'std_deviation': 0.123314105}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.02213311195373535 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.3950851, 'std_deviation': 0.112975076}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.027676105499267578 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.42133152, 'std_deviation': 0.102553055}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.004124879837036133 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.48955694, 'std_deviation': 0.11965646}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0028009414672851562 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.40056032, 'std_deviation': 0.10521798}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05471372604370117 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.39732945, 'std_deviation': 0.12383289}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.004889011383056641 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.4574538, 'std_deviation': 0.10046536}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0052340030670166016 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'CVS job openings', 'average_sim': 0.37743208, 'std_deviation': 0.10518089}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.004644870758056641 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.4072101, 'std_deviation': 0.111054294}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.017644166946411133 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.42088395, 'std_deviation': 0.11683784}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.002927064895629883 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Calling out liars', 'average_sim': 0.3673752, 'std_deviation': 0.12475905}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.003496885299682617 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.32865262, 'std_deviation': 0.08393548}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.005931854248046875 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.36553234, 'std_deviation': 0.096492425}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.005068063735961914 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.43956652, 'std_deviation': 0.11176878}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0031659603118896484 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Origin of the vaccine', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.3715176, 'std_deviation': 0.08068181}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.03277707099914551 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Pro Trump and against Biden/Obama', 'average_sim': 0.3885487, 'std_deviation': 0.13778402}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05671501159667969 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Dispelling misinformation regarding death', 'average_sim': 0.4256568, 'std_deviation': 0.10924857}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0360112190246582 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Vaccine availability', 'average_sim': 0.4340539, 'std_deviation': 0.114017285}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0031862258911132812 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': '2nd dose side effects', 'average_sim': 0.34404346, 'std_deviation': 0.08774015}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.05844712257385254 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Comparisons to other virus vaccines', 'average_sim': 0.4156915, 'std_deviation': 0.11348175}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.02189016342163086 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Anger over mask mandates', 'average_sim': 0.45241526, 'std_deviation': 0.110283464}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.009197235107421875 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Reminders of the 2nd vaccine', 'average_sim': 0.41570202, 'std_deviation': 0.10741711}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.003688812255859375 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Origin of the vaccine', 'average_sim': 0.40056032, 'std_deviation': 0.10521796}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0008797645568847656 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Discussing vaccines in schools', 'average_sim': 0.553601, 'std_deviation': 0.11414528}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.022371768951416016 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Positive outcomes of vaccine', 'average_sim': 0.39370197, 'std_deviation': 0.11784909}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.005445241928100586 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine', 'average_sim': 0.43635938, 'std_deviation': 0.099441886}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0034530162811279297 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'CVS job openings', 'average_sim': 0.42935804, 'std_deviation': 0.11460568}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.004324913024902344 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Information aimed towards minority communities', 'average_sim': 0.44534656, 'std_deviation': 0.104369566}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.003815174102783203 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Against anti-vaxxers', 'average_sim': 0.42146742, 'std_deviation': 0.11239318}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0077550411224365234 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Calling out liars', 'average_sim': 0.37932885, 'std_deviation': 0.11880838}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0051457881927490234 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Free food for vaccinated people', 'average_sim': 0.3941434, 'std_deviation': 0.090193264}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0016930103302001953 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Vaccine card mandates', 'average_sim': 0.3900197, 'std_deviation': 0.09650201}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.0029439926147460938 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Vaccine hesistancy', 'average_sim': 0.39758593, 'std_deviation': 0.107781865}
# --------
#
# Completed 1/15 combinations.
# Total time to calc : 0.000986337661743164 seconds.
# {'anno1': 'async_1', 'anno2': 'async_1', 'anno1_theme': 'Discussing vaccines in schools', 'anno2_theme': 'Vaccine appointment info', 'average_sim': 0.3810218, 'std_deviation': 0.08198582}
# --------
#
# Completed 1/15 combinations.
# ...
# Total time to calc : 0.013921976089477539 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Vaccine Eligibility Updates', 'average_sim': 0.42162195, 'std_deviation': 0.10880591}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.004624128341674805 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Proof of Vaccination(vaccine card/passport)', 'average_sim': 0.40964618, 'std_deviation': 0.11113183}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.002234935760498047 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': "Adverse Childhood Experience's being casued by COVID", 'average_sim': 0.44704047, 'std_deviation': 0.10369703}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0007169246673583984 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'COVID Vaccine causing Blood Clots', 'average_sim': 0.506033, 'std_deviation': 0.1056645}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0034461021423339844 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Become a Pharmacy Technician Alerts', 'average_sim': 0.40421036, 'std_deviation': 0.10719511}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0031821727752685547 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'COVID FDA Approval Status', 'average_sim': 0.6589673, 'std_deviation': 0.123569846}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0004291534423828125 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Anger Towards Republicans Lying about COVID', 'average_sim': 0.402428, 'std_deviation': 0.13123688}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0009031295776367188 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'average_sim': 0.41557398, 'std_deviation': 0.10389679}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.00830698013305664 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'COVID FDA Approval Status', 'anno2_theme': 'Walgreens Vaccine Appointment Updates', 'average_sim': 0.4274143, 'std_deviation': 0.0709587}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.026037931442260742 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Anti-Biden and Pro-Trump Sentiment', 'average_sim': 0.3823043, 'std_deviation': 0.11782768}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.00833582878112793 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Comparing the COVID Vaccine to other Deadly Disease Vaccines(polio,measles)', 'average_sim': 0.3811182, 'std_deviation': 0.117434494}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.18939495086669922 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Anger towards COVID Deniers/COVID Deniers Passing Away', 'average_sim': 0.38063386, 'std_deviation': 0.12555486}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.01918196678161621 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Immediate After-Effects from COVID Vaccine(soreness,nausea)', 'average_sim': 0.31848946, 'std_deviation': 0.115057096}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.044528961181640625 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Family Members Receiving the COVID Vaccine', 'average_sim': 0.35131535, 'std_deviation': 0.12115437}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.03678488731384277 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Vaccine Eligibility Updates', 'average_sim': 0.35096648, 'std_deviation': 0.1246106}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.020460128784179688 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Proof of Vaccination(vaccine card/passport)', 'average_sim': 0.37007114, 'std_deviation': 0.111417845}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.04294133186340332 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': "Adverse Childhood Experience's being casued by COVID", 'average_sim': 0.37111187, 'std_deviation': 0.12301858}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.04822278022766113 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'COVID Vaccine causing Blood Clots', 'average_sim': 0.4081051, 'std_deviation': 0.11752569}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.015956878662109375 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Become a Pharmacy Technician Alerts', 'average_sim': 0.35511318, 'std_deviation': 0.11809292}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.009959936141967773 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'COVID FDA Approval Status', 'average_sim': 0.40242806, 'std_deviation': 0.13123688}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.023844242095947266 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Anger Towards Republicans Lying about COVID', 'average_sim': 0.43845987, 'std_deviation': 0.15606187}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.05755305290222168 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'average_sim': 0.40569425, 'std_deviation': 0.1079043}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.011521100997924805 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Anger Towards Republicans Lying about COVID', 'anno2_theme': 'Walgreens Vaccine Appointment Updates', 'average_sim': 0.33859044, 'std_deviation': 0.1177831}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.008520126342773438 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Anti-Biden and Pro-Trump Sentiment', 'average_sim': 0.3940513, 'std_deviation': 0.11534295}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.008045673370361328 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Comparing the COVID Vaccine to other Deadly Disease Vaccines(polio,measles)', 'average_sim': 0.41467032, 'std_deviation': 0.097138695}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.1830580234527588 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Anger towards COVID Deniers/COVID Deniers Passing Away', 'average_sim': 0.41637948, 'std_deviation': 0.113187164}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.004930019378662109 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Immediate After-Effects from COVID Vaccine(soreness,nausea)', 'average_sim': 0.34021866, 'std_deviation': 0.092051454}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.028307199478149414 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Family Members Receiving the COVID Vaccine', 'average_sim': 0.41880217, 'std_deviation': 0.105453365}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.01148080825805664 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Vaccine Eligibility Updates', 'average_sim': 0.43294695, 'std_deviation': 0.10262449}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.02041029930114746 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Proof of Vaccination(vaccine card/passport)', 'average_sim': 0.408121, 'std_deviation': 0.09872283}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0033228397369384766 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': "Adverse Childhood Experience's being casued by COVID", 'average_sim': 0.40020564, 'std_deviation': 0.104300834}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.007547140121459961 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'COVID Vaccine causing Blood Clots', 'average_sim': 0.42584768, 'std_deviation': 0.09068195}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.01739811897277832 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Become a Pharmacy Technician Alerts', 'average_sim': 0.46230337, 'std_deviation': 0.11048833}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.001001119613647461 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'COVID FDA Approval Status', 'average_sim': 0.41557398, 'std_deviation': 0.10389679}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0010302066802978516 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Anger Towards Republicans Lying about COVID', 'average_sim': 0.40569428, 'std_deviation': 0.1079043}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0005869865417480469 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'average_sim': 0.54838455, 'std_deviation': 0.12565157}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0012941360473632812 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'anno2_theme': 'Walgreens Vaccine Appointment Updates', 'average_sim': 0.40090123, 'std_deviation': 0.084410675}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.013772726058959961 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Anti-Biden and Pro-Trump Sentiment', 'average_sim': 0.3259646, 'std_deviation': 0.1146998}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0084991455078125 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Comparing the COVID Vaccine to other Deadly Disease Vaccines(polio,measles)', 'average_sim': 0.37433144, 'std_deviation': 0.07117471}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.1786642074584961 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Anger towards COVID Deniers/COVID Deniers Passing Away', 'average_sim': 0.36967555, 'std_deviation': 0.114079416}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.009986162185668945 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Immediate After-Effects from COVID Vaccine(soreness,nausea)', 'average_sim': 0.35383543, 'std_deviation': 0.058631606}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.038562774658203125 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Family Members Receiving the COVID Vaccine', 'average_sim': 0.4103051, 'std_deviation': 0.089867964}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.01139378547668457 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Vaccine Eligibility Updates', 'average_sim': 0.4908653, 'std_deviation': 0.10182123}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.007234811782836914 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Proof of Vaccination(vaccine card/passport)', 'average_sim': 0.3620639, 'std_deviation': 0.089918315}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0016410350799560547 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': "Adverse Childhood Experience's being casued by COVID", 'average_sim': 0.37819907, 'std_deviation': 0.069585405}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.018166065216064453 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'COVID Vaccine causing Blood Clots', 'average_sim': 0.4053523, 'std_deviation': 0.07685611}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.009728670120239258 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Become a Pharmacy Technician Alerts', 'average_sim': 0.4842262, 'std_deviation': 0.10283525}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0020868778228759766 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'COVID FDA Approval Status', 'average_sim': 0.42741433, 'std_deviation': 0.0709587}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0022749900817871094 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Anger Towards Republicans Lying about COVID', 'average_sim': 0.33859044, 'std_deviation': 0.1177831}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0029098987579345703 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Giving Info about COVID and the Vaccine to Minorities in America', 'average_sim': 0.4009012, 'std_deviation': 0.084410675}
# --------
#
# Completed 15/15 combinations.
# Total time to calc : 0.0015130043029785156 seconds.
# {'anno1': 'async_3', 'anno2': 'async_3', 'anno1_theme': 'Walgreens Vaccine Appointment Updates', 'anno2_theme': 'Walgreens Vaccine Appointment Updates', 'average_sim': 0.83444375, 'std_deviation': 0.062122833}
# --------

# %%
# Read from csv
# global_average_sims = pd.read_csv('./dataset/fang_system/std_dev_aggregated_sims.csv')

# %%
global_average_sims
# Out:
# [{'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.38501024,
#   'std_deviation': 0.1547931},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.3898052,
#   'std_deviation': 0.14515024},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.37891957,
#   'std_deviation': 0.14455523},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.3363732,
#   'std_deviation': 0.14243443},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.39129966,
#   'std_deviation': 0.1457191},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.38434565,
#   'std_deviation': 0.1346536},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.4026332,
#   'std_deviation': 0.15365437},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.3695131,
#   'std_deviation': 0.14634246},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.3885489,
#   'std_deviation': 0.137784},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.37368557,
#   'std_deviation': 0.1477749},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.42247492,
#   'std_deviation': 0.14317353},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.38257772,
#   'std_deviation': 0.14186633},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.4047892,
#   'std_deviation': 0.13275492},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.39683333,
#   'std_deviation': 0.13732965},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.37181616,
#   'std_deviation': 0.1346197},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.35570058,
#   'std_deviation': 0.11467385},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.3428388,
#   'std_deviation': 0.12922953},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.39207807,
#   'std_deviation': 0.14812693},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.33529457,
#   'std_deviation': 0.13245264},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.38980663,
#   'std_deviation': 0.14515035},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.47539994,
#   'std_deviation': 0.12187069},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.40216896,
#   'std_deviation': 0.11407772},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.41694498,
#   'std_deviation': 0.11490212},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.44650927,
#   'std_deviation': 0.124650225},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.41672346,
#   'std_deviation': 0.11214667},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.43299904,
#   'std_deviation': 0.10789266},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.45822018,
#   'std_deviation': 0.11857446},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.42565686,
#   'std_deviation': 0.10924858},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.4106254,
#   'std_deviation': 0.12531546},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.47023204,
#   'std_deviation': 0.10385456},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.3922389,
#   'std_deviation': 0.10996948},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.4299438,
#   'std_deviation': 0.11053873},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.4438186,
#   'std_deviation': 0.12016304},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.39215276,
#   'std_deviation': 0.12693447},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.3451126,
#   'std_deviation': 0.08374293},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.37024868,
#   'std_deviation': 0.09906219},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.4455813,
#   'std_deviation': 0.11335425},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.3730554,
#   'std_deviation': 0.081730254},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.37891874,
#   'std_deviation': 0.14455523},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.40216964,
#   'std_deviation': 0.114077896},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.4639409,
#   'std_deviation': 0.12192754},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.37096512,
#   'std_deviation': 0.1092507},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.39693412,
#   'std_deviation': 0.11954626},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.3977574,
#   'std_deviation': 0.111303836},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.45629987,
#   'std_deviation': 0.120908394},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.38428915,
#   'std_deviation': 0.11186808},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.43405366,
#   'std_deviation': 0.11401732},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.40870735,
#   'std_deviation': 0.12572786},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.44425347,
#   'std_deviation': 0.109307565},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.46542674,
#   'std_deviation': 0.1177203},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.432888,
#   'std_deviation': 0.11467023},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.39035293,
#   'std_deviation': 0.118388645},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.35515475,
#   'std_deviation': 0.12520638},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.4016851,
#   'std_deviation': 0.08959309},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.39228043,
#   'std_deviation': 0.09829791},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.3953222,
#   'std_deviation': 0.11450304},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.4737113,
#   'std_deviation': 0.12463807},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.3363733,
#   'std_deviation': 0.14243436},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.41694513,
#   'std_deviation': 0.11490207},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.37096515,
#   'std_deviation': 0.10925071},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.64759964,
#   'std_deviation': 0.1139642},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.40508303,
#   'std_deviation': 0.1233618},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.33633068,
#   'std_deviation': 0.09955824},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.5001619,
#   'std_deviation': 0.118069895},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.41363743,
#   'std_deviation': 0.10534762},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.34404346,
#   'std_deviation': 0.08774015},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.43038416,
#   'std_deviation': 0.13067634},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.4246004,
#   'std_deviation': 0.091741644},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.3655481,
#   'std_deviation': 0.104249775},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.34731266,
#   'std_deviation': 0.10055406},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.36853683,
#   'std_deviation': 0.10949332},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.31432924,
#   'std_deviation': 0.111860886},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.31557122,
#   'std_deviation': 0.072336294},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.32423574,
#   'std_deviation': 0.0839163},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.38402423,
#   'std_deviation': 0.09835339},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': '2nd dose side effects',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.35528582,
#   'std_deviation': 0.060164005},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.39130214,
#   'std_deviation': 0.14571951},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.44650862,
#   'std_deviation': 0.12465013},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.39693445,
#   'std_deviation': 0.119546264},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.40508354,
#   'std_deviation': 0.123361744},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.44625092,
#   'std_deviation': 0.128377},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.41600585,
#   'std_deviation': 0.115175985},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.43174526,
#   'std_deviation': 0.120694645},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.43550637,
#   'std_deviation': 0.1233141},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.41569158,
#   'std_deviation': 0.1134818},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.41251984,
#   'std_deviation': 0.12984687},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.4466512,
#   'std_deviation': 0.108511485},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.39074135,
#   'std_deviation': 0.115883335},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.42031536,
#   'std_deviation': 0.112503685},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.44030696,
#   'std_deviation': 0.122057855},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.38614136,
#   'std_deviation': 0.12448876},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.36615753,
#   'std_deviation': 0.09182869},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.37994868,
#   'std_deviation': 0.10687692},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.43192813,
#   'std_deviation': 0.12040993},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Comparisons to other virus vaccines',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.36326253,
#   'std_deviation': 0.091716506},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.38434508,
#   'std_deviation': 0.13465361},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.4167234,
#   'std_deviation': 0.11214662},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.3977577,
#   'std_deviation': 0.11130393},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.3363308,
#   'std_deviation': 0.09955825},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.41600573,
#   'std_deviation': 0.11517596},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.4598717,
#   'std_deviation': 0.11578519},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.3946458,
#   'std_deviation': 0.106089026},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.395085,
#   'std_deviation': 0.112975076},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.45241532,
#   'std_deviation': 0.11028345},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.3833476,
#   'std_deviation': 0.11803612},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.42379522,
#   'std_deviation': 0.099856764},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.39086366,
#   'std_deviation': 0.10867556},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.41652155,
#   'std_deviation': 0.10283946},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.4232371,
#   'std_deviation': 0.111384004},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.37605786,
#   'std_deviation': 0.11614486},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.36378366,
#   'std_deviation': 0.0850274},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.38984942,
#   'std_deviation': 0.0991505},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.40430412,
#   'std_deviation': 0.10715101},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Anger over mask mandates',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.34795895,
#   'std_deviation': 0.0868498},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.40263373,
#   'std_deviation': 0.15365437},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.43299973,
#   'std_deviation': 0.10789269},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.45629948,
#   'std_deviation': 0.12090835},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.5001616,
#   'std_deviation': 0.118069865},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.43174562,
#   'std_deviation': 0.12069463},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.39464614,
#   'std_deviation': 0.106089026},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.5648231,
#   'std_deviation': 0.13067836},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.42133185,
#   'std_deviation': 0.1025531},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.41570196,
#   'std_deviation': 0.10741709},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.47438118,
#   'std_deviation': 0.13291909},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.4761472,
#   'std_deviation': 0.10308998},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.47220644,
#   'std_deviation': 0.1227936},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.43718624,
#   'std_deviation': 0.111106545},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.41131592,
#   'std_deviation': 0.113755986},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.36000326,
#   'std_deviation': 0.11858574},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.4087625,
#   'std_deviation': 0.08656166},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.37830433,
#   'std_deviation': 0.093207724},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.42605135,
#   'std_deviation': 0.116308376},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Reminders of the 2nd vaccine',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.42647555,
#   'std_deviation': 0.07515451},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.3695132,
#   'std_deviation': 0.14634249},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.45822054,
#   'std_deviation': 0.11857443},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.38428938,
#   'std_deviation': 0.11186812},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.41363743,
#   'std_deviation': 0.105347626},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.4355066,
#   'std_deviation': 0.123314105},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.3950851,
#   'std_deviation': 0.112975076},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.42133152,
#   'std_deviation': 0.102553055},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.48955694,
#   'std_deviation': 0.11965646},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.40056032,
#   'std_deviation': 0.10521798},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.39732945,
#   'std_deviation': 0.12383289},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.4574538,
#   'std_deviation': 0.10046536},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.37743208,
#   'std_deviation': 0.10518089},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.4072101,
#   'std_deviation': 0.111054294},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.42088395,
#   'std_deviation': 0.11683784},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.3673752,
#   'std_deviation': 0.12475905},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.32865262,
#   'std_deviation': 0.08393548},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.36553234,
#   'std_deviation': 0.096492425},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.43956652,
#   'std_deviation': 0.11176878},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Origin of the vaccine',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.3715176,
#   'std_deviation': 0.08068181},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.3885487,
#   'std_deviation': 0.13778402},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.4256568,
#   'std_deviation': 0.10924857},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.4340539,
#   'std_deviation': 0.114017285},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.34404346,
#   'std_deviation': 0.08774015},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.4156915,
#   'std_deviation': 0.11348175},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.45241526,
#   'std_deviation': 0.110283464},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.41570202,
#   'std_deviation': 0.10741711},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.40056032,
#   'std_deviation': 0.10521796},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.553601,
#   'std_deviation': 0.11414528},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.39370197,
#   'std_deviation': 0.11784909},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.43635938,
#   'std_deviation': 0.099441886},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.42935804,
#   'std_deviation': 0.11460568},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.44534656,
#   'std_deviation': 0.104369566},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.42146742,
#   'std_deviation': 0.11239318},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.37932885,
#   'std_deviation': 0.11880838},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.3941434,
#   'std_deviation': 0.090193264},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.3900197,
#   'std_deviation': 0.09650201},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.39758593,
#   'std_deviation': 0.107781865},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Discussing vaccines in schools',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.3810218,
#   'std_deviation': 0.08198582},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.37368494,
#   'std_deviation': 0.14777479},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.4106269,
#   'std_deviation': 0.1253156},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.40870753,
#   'std_deviation': 0.1257278},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.43038362,
#   'std_deviation': 0.13067642},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.4125204,
#   'std_deviation': 0.12984696},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.38334787,
#   'std_deviation': 0.11803614},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.47438133,
#   'std_deviation': 0.13291904},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.39732954,
#   'std_deviation': 0.12383293},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.39370197,
#   'std_deviation': 0.11784913},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.43110937,
#   'std_deviation': 0.13512935},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.42583266,
#   'std_deviation': 0.114707805},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.41722125,
#   'std_deviation': 0.122756355},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.40700036,
#   'std_deviation': 0.117383614},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.40563157,
#   'std_deviation': 0.1262599},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.34864557,
#   'std_deviation': 0.124419935},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.37557036,
#   'std_deviation': 0.09355282},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.3633668,
#   'std_deviation': 0.10767285},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.390162,
#   'std_deviation': 0.124199174},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Positive outcomes of vaccine',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.3742631,
#   'std_deviation': 0.09766315},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.42247477,
#   'std_deviation': 0.1431736},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.47023204,
#   'std_deviation': 0.103854544},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.44425353,
#   'std_deviation': 0.109307535},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.4246005,
#   'std_deviation': 0.09174165},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.44665164,
#   'std_deviation': 0.1085115},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.42379537,
#   'std_deviation': 0.09985678},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.47614726,
#   'std_deviation': 0.10308996},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.45745385,
#   'std_deviation': 0.10046536},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.43635938,
#   'std_deviation': 0.09944188},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.42583266,
#   'std_deviation': 0.11470778},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.585338,
#   'std_deviation': 0.115568265},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.435977,
#   'std_deviation': 0.105289154},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.44969684,
#   'std_deviation': 0.100282595},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.43491665,
#   'std_deviation': 0.10397381},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.41861984,
#   'std_deviation': 0.12274949},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.38304377,
#   'std_deviation': 0.07805874},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.38942376,
#   'std_deviation': 0.08823136},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.53354174,
#   'std_deviation': 0.11857819},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.43809998,
#   'std_deviation': 0.069227174},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.38257834,
#   'std_deviation': 0.14186628},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.39223877,
#   'std_deviation': 0.10996949},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.4654265,
#   'std_deviation': 0.11772033},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.36554807,
#   'std_deviation': 0.10424977},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.39074028,
#   'std_deviation': 0.11588336},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.39086384,
#   'std_deviation': 0.108675584},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.47220618,
#   'std_deviation': 0.122793585},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.3774321,
#   'std_deviation': 0.10518089},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Discussing vaccines in schools',
#   'average_sim': 0.42935804,
#   'std_deviation': 0.11460568},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Positive outcomes of vaccine',
#   'average_sim': 0.41722077,
#   'std_deviation': 0.122756325},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Concerns regarding Johnson and Johnson vaccine',
#   'average_sim': 0.43597692,
#   'std_deviation': 0.10528915},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'CVS job openings',
#   'average_sim': 0.5124516,
#   'std_deviation': 0.12498533},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Information aimed towards minority communities',
#   'average_sim': 0.45109332,
#   'std_deviation': 0.11928315},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Against anti-vaxxers',
#   'average_sim': 0.3914382,
#   'std_deviation': 0.11672473},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Calling out liars',
#   'average_sim': 0.3480652,
#   'std_deviation': 0.11877103},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Free food for vaccinated people',
#   'average_sim': 0.41648227,
#   'std_deviation': 0.09112157},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Vaccine card mandates',
#   'average_sim': 0.387593,
#   'std_deviation': 0.09603},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Vaccine hesistancy',
#   'average_sim': 0.38094497,
#   'std_deviation': 0.1079157},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'CVS job openings',
#   'anno2_theme': 'Vaccine appointment info',
#   'average_sim': 0.46755734,
#   'std_deviation': 0.102603294},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Pro Trump and against Biden/Obama',
#   'average_sim': 0.40478903,
#   'std_deviation': 0.13275494},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Dispelling misinformation regarding death',
#   'average_sim': 0.4299439,
#   'std_deviation': 0.110538706},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Vaccine availability',
#   'average_sim': 0.43288803,
#   'std_deviation': 0.11467024},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': '2nd dose side effects',
#   'average_sim': 0.34731266,
#   'std_deviation': 0.10055406},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Comparisons to other virus vaccines',
#   'average_sim': 0.4203148,
#   'std_deviation': 0.112503685},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Anger over mask mandates',
#   'average_sim': 0.41652134,
#   'std_deviation': 0.10283946},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Reminders of the 2nd vaccine',
#   'average_sim': 0.43718642,
#   'std_deviation': 0.11110656},
#  {'anno1': 'async_1',
#   'anno2': 'async_1',
#   'anno1_theme': 'Information aimed towards minority communities',
#   'anno2_theme': 'Origin of the vaccine',
#   'average_sim': 0.4072101,
#   'std_deviation': 0.111054294},
# ...
#   'std_deviation': 0.09466227},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine card mandates',
#   'anno2_theme': 'vaccine side effects/ Nicki Minaj',
#   'average_sim': 0.3483389,
#   'std_deviation': 0.09649065},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine card mandates',
#   'anno2_theme': 'covid appointment',
#   'average_sim': 0.3935356,
#   'std_deviation': 0.07279985},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': "criticism of governments' response to vaccine",
#   'average_sim': 0.39305294,
#   'std_deviation': 0.1420934},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'family covid vaccine experience',
#   'average_sim': 0.41075158,
#   'std_deviation': 0.12292233},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'immediate personal side effects',
#   'average_sim': 0.3844081,
#   'std_deviation': 0.09825011},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'state vaccine eligibility',
#   'average_sim': 0.3859976,
#   'std_deviation': 0.10554447},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'non-covid vaccine comparision',
#   'average_sim': 0.44550318,
#   'std_deviation': 0.10812575},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'institutional adverse childhood experiences',
#   'average_sim': 0.44740054,
#   'std_deviation': 0.10958475},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'vaccine certification',
#   'average_sim': 0.39595044,
#   'std_deviation': 0.10831327},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'anti-vaccine conspiracy outcomes',
#   'average_sim': 0.42773393,
#   'std_deviation': 0.12611176},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'Error',
#   'average_sim': 0.48941177,
#   'std_deviation': 0.1123952},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'pharmacy hiring',
#   'average_sim': 0.37713605,
#   'std_deviation': 0.10597822},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'FDA vaccine approval',
#   'average_sim': 0.59819573,
#   'std_deviation': 0.14228824},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'long term side effects',
#   'average_sim': 0.45626974,
#   'std_deviation': 0.102525376},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'community vaccine equity',
#   'average_sim': 0.40701494,
#   'std_deviation': 0.10898018},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'vaccine side effects/ Nicki Minaj',
#   'average_sim': 0.4114532,
#   'std_deviation': 0.11123961},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine hesistancy',
#   'anno2_theme': 'covid appointment',
#   'average_sim': 0.39046904,
#   'std_deviation': 0.0743391},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': "criticism of governments' response to vaccine",
#   'average_sim': 0.33587018,
#   'std_deviation': 0.13046476},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'family covid vaccine experience',
#   'average_sim': 0.40236813,
#   'std_deviation': 0.0972176},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'immediate personal side effects',
#   'average_sim': 0.3523092,
#   'std_deviation': 0.059780933},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'state vaccine eligibility',
#   'average_sim': 0.49426356,
#   'std_deviation': 0.10651319},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'non-covid vaccine comparision',
#   'average_sim': 0.37919784,
#   'std_deviation': 0.071250916},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'institutional adverse childhood experiences',
#   'average_sim': 0.372646,
#   'std_deviation': 0.07478989},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'vaccine certification',
#   'average_sim': 0.36597383,
#   'std_deviation': 0.089774124},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'anti-vaccine conspiracy outcomes',
#   'average_sim': 0.35555413,
#   'std_deviation': 0.10391789},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'Error',
#   'average_sim': 0.40377828,
#   'std_deviation': 0.074354835},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'pharmacy hiring',
#   'average_sim': 0.46689877,
#   'std_deviation': 0.102117956},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'FDA vaccine approval',
#   'average_sim': 0.42115214,
#   'std_deviation': 0.07457097},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'long term side effects',
#   'average_sim': 0.3733218,
#   'std_deviation': 0.06486359},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'community vaccine equity',
#   'average_sim': 0.39287382,
#   'std_deviation': 0.08742047},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'vaccine side effects/ Nicki Minaj',
#   'average_sim': 0.36760846,
#   'std_deviation': 0.10713198},
#  {'anno1': 'async_1',
#   'anno2': 'group_2',
#   'anno1_theme': 'Vaccine appointment info',
#   'anno2_theme': 'covid appointment',
#   'average_sim': 0.82013005,
#   'std_deviation': 0.0757035},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineRolloutNews',
#   'average_sim': 0.3815998,
#   'std_deviation': 0.14383483},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'AntiTrump',
#   'average_sim': 0.38659978,
#   'std_deviation': 0.14505298},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineSideEffects',
#   'average_sim': 0.3341476,
#   'std_deviation': 0.14175591},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineTestScience',
#   'average_sim': 0.39343497,
#   'std_deviation': 0.14442585},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'HopefulPeopleGetVaccinated',
#   'average_sim': 0.3870164,
#   'std_deviation': 0.15194696},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'WhereToGetVaccine',
#   'average_sim': 0.33754185,
#   'std_deviation': 0.13433436},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'FDANews&Discourse',
#   'average_sim': 0.41875482,
#   'std_deviation': 0.14793724},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccinePassportNews',
#   'average_sim': 0.36774606,
#   'std_deviation': 0.13254291},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'FakeNews',
#   'average_sim': 0.3790435,
#   'std_deviation': 0.13873419},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineAdvocacy',
#   'average_sim': 0.37540826,
#   'std_deviation': 0.1483603},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'AntiRepublican',
#   'average_sim': 0.38719618,
#   'std_deviation': 0.13970703},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'AntiDemocrat',
#   'average_sim': 0.38736722,
#   'std_deviation': 0.1470239},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'PandemicNews',
#   'average_sim': 0.39088866,
#   'std_deviation': 0.13831148},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineHesitancy',
#   'average_sim': 0.36337855,
#   'std_deviation': 0.14691243},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'POCVaccineAwareness',
#   'average_sim': 0.4005465,
#   'std_deviation': 0.13002257},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'FightingDisinformation',
#   'average_sim': 0.35775822,
#   'std_deviation': 0.1224969},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineChildRisk',
#   'average_sim': 0.37541038,
#   'std_deviation': 0.14312844},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Pro Trump and against Biden/Obama',
#   'anno2_theme': 'VaccineProblemsNews',
#   'average_sim': 0.4052143,
#   'std_deviation': 0.13702817},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineRolloutNews',
#   'average_sim': 0.40555596,
#   'std_deviation': 0.119922355},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'AntiTrump',
#   'average_sim': 0.42490712,
#   'std_deviation': 0.13556413},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineSideEffects',
#   'average_sim': 0.41857913,
#   'std_deviation': 0.11692156},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineTestScience',
#   'average_sim': 0.47074038,
#   'std_deviation': 0.11792392},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'HopefulPeopleGetVaccinated',
#   'average_sim': 0.42107543,
#   'std_deviation': 0.12710111},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'WhereToGetVaccine',
#   'average_sim': 0.37060648,
#   'std_deviation': 0.08989378},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'FDANews&Discourse',
#   'average_sim': 0.47046417,
#   'std_deviation': 0.105619326},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccinePassportNews',
#   'average_sim': 0.39300016,
#   'std_deviation': 0.10782021},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'FakeNews',
#   'average_sim': 0.43663126,
#   'std_deviation': 0.12111627},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineAdvocacy',
#   'average_sim': 0.50220084,
#   'std_deviation': 0.12303706},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'AntiRepublican',
#   'average_sim': 0.39092687,
#   'std_deviation': 0.12679827},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'AntiDemocrat',
#   'average_sim': 0.42878458,
#   'std_deviation': 0.13896488},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'PandemicNews',
#   'average_sim': 0.45831403,
#   'std_deviation': 0.11502762},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineHesitancy',
#   'average_sim': 0.46181068,
#   'std_deviation': 0.11767653},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'POCVaccineAwareness',
#   'average_sim': 0.42255035,
#   'std_deviation': 0.10894443},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'FightingDisinformation',
#   'average_sim': 0.3882007,
#   'std_deviation': 0.10920057},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineChildRisk',
#   'average_sim': 0.4743971,
#   'std_deviation': 0.11087861},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Dispelling misinformation regarding death',
#   'anno2_theme': 'VaccineProblemsNews',
#   'average_sim': 0.46452618,
#   'std_deviation': 0.10407391},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccineRolloutNews',
#   'average_sim': 0.4522877,
#   'std_deviation': 0.124666795},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'AntiTrump',
#   'average_sim': 0.3693097,
#   'std_deviation': 0.12474897},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccineSideEffects',
#   'average_sim': 0.3666102,
#   'std_deviation': 0.108823776},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccineTestScience',
#   'average_sim': 0.41379735,
#   'std_deviation': 0.11189652},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'HopefulPeopleGetVaccinated',
#   'average_sim': 0.4193976,
#   'std_deviation': 0.13035323},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'WhereToGetVaccine',
#   'average_sim': 0.46715465,
#   'std_deviation': 0.12185264},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'FDANews&Discourse',
#   'average_sim': 0.4353311,
#   'std_deviation': 0.111393556},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccinePassportNews',
#   'average_sim': 0.39951617,
#   'std_deviation': 0.10864734},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'FakeNews',
#   'average_sim': 0.38187164,
#   'std_deviation': 0.1110356},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccineAdvocacy',
#   'average_sim': 0.38707745,
#   'std_deviation': 0.10870766},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'AntiRepublican',
#   'average_sim': 0.3819798,
#   'std_deviation': 0.1260379},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'AntiDemocrat',
#   'average_sim': 0.37567627,
#   'std_deviation': 0.12633984},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'PandemicNews',
#   'average_sim': 0.39955106,
#   'std_deviation': 0.108754046},
#  {'anno1': 'async_1',
#   'anno2': 'async_2',
#   'anno1_theme': 'Vaccine availability',
#   'anno2_theme': 'VaccineHesitancy',
#   'average_sim': 0.37615266,
#   'std_deviation': 0.10664718},
#  ...]

# %%
global_average_df = pd.DataFrame(global_average_sims)

# %% [markdown]
# ### 4.b. Calculating Synchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(synchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)

print("Synchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Synchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.51
# Standard Deviation of Group Cosine Similarity: 0.10
# anno1            16
# anno2            16
# anno1_theme      16
# anno2_theme      16
# average_sim      16
# std_deviation    16
# dtype: int64

# %% [markdown]
# ### 4.c. Calculating Asynchronous Group Average Cosine Similarities

# %%
max_cosine_sims = []

for anno_1 , anno_2 in itertools.permutations(asynchronous_annotators , 2):
    filtered_df = global_average_df[(global_average_df['anno1'] == anno_1)&
                                    (global_average_df['anno2'] == anno_2)]
    for anno_1_theme in filtered_df['anno1_theme'].unique(): 
        if ('kmeans' not in anno_1_theme.lower()) and ('unknown' not in anno_1_theme.lower()):
            theme_filtered_df  = filtered_df[(filtered_df['anno1_theme'] == anno_1_theme) &
                                              ~(filtered_df['anno2_theme'].str.contains('Kmeans')) &
                                              ~(filtered_df['anno2_theme'].str.contains('Unknown'))]
            max_cosine_sims.append(theme_filtered_df.loc[(theme_filtered_df['average_sim'].idxmax())].to_dict())
 
res_df = pd.DataFrame(max_cosine_sims)


print("Asynchronous Group Average Cosine Similarity")
print(f"Average Max Group Cosine Similarity: {res_df['average_sim'].mean():.2f}")
print(f"Standard Deviation of Group Cosine Similarity: { res_df['average_sim'].std():.2f}")

print(res_df.count())
# Out:
# Asynchronous Group Average Cosine Similarity
# Average Max Group Cosine Similarity: 0.50
# Standard Deviation of Group Cosine Similarity: 0.09
# anno1            56
# anno2            56
# anno1_theme      56
# anno2_theme      56
# average_sim      56
# std_deviation    56
# dtype: int64

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Getting top 25th percentile of highest weights

# %%
results = []

for annotator, df in annotator2df.items(): 
    cosine_sims = []
    themes = []
    for i , theme in enumerate(df['name'].unique()): 
        if ('kmeans' not in theme.lower()) and ('unknown' not in theme.lower()): 
            result = {'annotator' : annotator}
            ids = df[df['name'] == theme]['tweet_id'].tolist()
            result['theme'] = theme
            result['tweets'] = df[df['name'] == theme]['text'].tolist()
            result['weights'] = df[df['name'] == theme]['weight'].tolist()

            theme_vectors = sbert_vectors[ids]
            theme_centroid = np.average(theme_vectors, axis=0, keepdims=True)

            result['theme_centroid'] = theme_centroid
            result['theme_vectors'] = theme_vectors

            dot_prod = np.dot(theme_centroid , theme_vectors.T).squeeze(0)
            dot_prod = np.expand_dims(dot_prod , axis=-1)

            norm = np.linalg.norm(theme_vectors , axis=1, keepdims=True)
            cosine_sim = (dot_prod/norm)
            result['cosine_sim']  = cosine_sim.squeeze() 
            results.append(result)

# %%
top_25_results = {'top_25_tweets':[],
                  'top_25_vectors' : [], 
                  'theme' : [], 
                  'annotator' : []}

for result in results: 

    m = np.percentile(result['weights'] , 75)
    top_25_indices = np.where(result['weights']>m)
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results['top_25_tweets'].extend(top_25_tweets)
    top_25_results['top_25_vectors'].extend(top_25_vectors )
    top_25_results['theme'].extend([theme]*top_25_tweets.shape[0])
    top_25_results['annotator'].extend([annotator]*top_25_tweets.shape[0])


top_25_df = pd.DataFrame(top_25_results, columns=['theme' , 'annotator' , 'top_25_tweets'])

# %% [markdown]
# ### 4.a. Random Sampling rows for manual annotations

# %%
sync_top_25 = top_25_df[top_25_df['annotator'].isin(synchronous_annotators)].sample(n=200)[['theme' , 'top_25_tweets']]
async_top_25 = top_25_df[top_25_df['annotator'].isin(asynchronous_annotators)].sample(n=200)[['theme' , 'top_25_tweets']]

sync_top_25.to_csv('./dataset/generated_samples/fang_sync_sample_top25.csv' , index=False, sep='\t')
async_top_25.to_csv('./dataset/generated_samples/fang_async_sample_top25.csv' , index=False, sep='\t')

# %% [markdown]
# ____

# %% [markdown]
# ## 5. Calculating Intra- and Inter-cluster Similarity

# %%
top_25_results = {}

for result in results: 

    top_25_results[result['theme']] = {}

    m = np.percentile(result['weights'] , 75)
    top_25_indices = np.where(result['weights']>m)
    top_25_vectors = result['theme_vectors'][top_25_indices]
    top_25_tweets = np.array(result['tweets'])[top_25_indices]
    annotator=result['annotator']
    theme=result['theme']

    top_25_results[theme]['top_25_tweets'] = (top_25_tweets)
    top_25_results[theme]['top_25_vectors'] = (top_25_vectors )
    top_25_results[theme]['annotator'] = (annotator)

# %% [markdown]
# ### 5.a. Calculating similarities for top 25th percentile clusters

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_25_average_sims = []

for anno_1_theme , anno1_top_25 in tqdm(top_25_results.items()): 
    for anno_2_theme , anno2_top_25 in top_25_results.items(): 

        anno1_top_25_vectors = anno1_top_25['top_25_vectors']
        anno2_top_25_vectors = anno2_top_25['top_25_vectors']

        cosine_sims = cosine_similarity(anno1_top_25_vectors , anno2_top_25_vectors)
        average_sim = np.average(cosine_sims)
        std_deviation = np.std(cosine_sims)

        top_25_average_sims.append({'anno_1' : anno1_top_25['annotator'] , 
                                   'anno_2' : anno2_top_25['annotator'], 
                                   'anno_1_theme' : anno_1_theme,
                                   'anno_2_theme' : anno_2_theme,
                                   'average_sim' : average_sim , 
                                   'std_dev_sim' : std_deviation})
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]

# %%
top_25_average_df = pd.DataFrame(top_25_average_sims)
top_25_average_df
# Out:
#        anno_1   anno_2                           anno_1_theme  \
# 0     async_1  async_1      Pro Trump and against Biden/Obama
# 1     async_1  async_1      Pro Trump and against Biden/Obama
# 2     async_1  async_1      Pro Trump and against Biden/Obama
# 3     async_1  async_1      Pro Trump and against Biden/Obama
# 4     async_1  async_1      Pro Trump and against Biden/Obama
# ...       ...      ...                                    ...
# 6719  async_3  async_3  Walgreens Vaccine Appointment Updates
# 6720  async_3  async_3  Walgreens Vaccine Appointment Updates
# 6721  async_3  async_3  Walgreens Vaccine Appointment Updates
# 6722  async_3  async_3  Walgreens Vaccine Appointment Updates
# 6723  async_3  async_3  Walgreens Vaccine Appointment Updates
#
#                                            anno_2_theme  average_sim  \
# 0                     Pro Trump and against Biden/Obama     0.436329
# 1             Dispelling misinformation regarding death     0.382954
# 2                                  Vaccine availability     0.340331
# 3                                 2nd dose side effects     0.297146
# 4                   Comparisons to other virus vaccines     0.393644
# ...                                                 ...          ...
# 6719                Become a Pharmacy Technician Alerts     0.508613
# 6720                          COVID FDA Approval Status     0.422161
# 6721        Anger Towards Republicans Lying about COVID     0.273490
# 6722  Giving Info about COVID and the Vaccine to Min...     0.407098
# 6723              Walgreens Vaccine Appointment Updates     0.862829
#
#       std_dev_sim
# 0        0.130776
# 1        0.124816
# 2        0.121193
# 3        0.105271
# 4        0.123845
# ...           ...
# 6719     0.086481
# 6720     0.078194
# 6721     0.080248
# 6722     0.075590
# 6723     0.057535
#
# [6724 rows x 6 columns]

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']==top_25_average_df['anno_2_theme'])]

# %% [markdown]
# ### 5.b. Intra- and Inter-theme similarities for top 25th percentile subsets in synchronous and asynchronous experiments

# %%
print(f"Synchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% intra theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% intra theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% intra theme similarity average: 0.56
# Synchronous top 25% intra theme similarity standard deviation: 0.11
# Asynchronous top 25% intra theme similarity average: 0.56
# Asynchronous top 25% intra theme similarity standard deviation: 0.11

# %%
top_25_intra_cluster_df = top_25_average_df[(top_25_average_df['anno_1']==top_25_average_df['anno_2']) & (top_25_average_df['anno_1_theme']!=top_25_average_df['anno_2_theme'])]

# %%
print(f"Synchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous top 25% inter theme similarity average: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous top 25% inter theme similarity standard deviation: {top_25_intra_cluster_df[top_25_intra_cluster_df['anno_1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous top 25% inter theme similarity average: 0.39
# Synchronous top 25% inter theme similarity standard deviation: 0.05
# Asynchronous top 25% inter theme similarity average: 0.39
# Asynchronous top 25% inter theme similarity standard deviation: 0.05

# %% [markdown]
# ### 5.c. Intra- and Inter-theme similarities for whole set in synchronous and asynchronous experiments

# %%
global_average_df = pd.DataFrame(global_average_sims)

intra_global_average_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']==global_average_df['anno2_theme'])] 


print(f"Synchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global intra theme similarity average: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global intra theme similarity standard deviation: {intra_global_average_df[intra_global_average_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global intra theme similarity average: 0.52
# Synchronous global intra theme similarity standard deviation: 0.10
# Asynchronous global intra theme similarity average: 0.52
# Asynchronous global intra theme similarity standard deviation: 0.10

# %%
inter_global_avg_df = global_average_df[(global_average_df['anno1']==global_average_df['anno2']) & (global_average_df['anno1_theme']!=global_average_df['anno2_theme'])] 

print(f"Synchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Synchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(synchronous_annotators)]['average_sim'].std():.2f}")


print(f"Asynchronous global inter theme similarity average: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].mean():.2f}")
print(f"Asynchronous global inter theme similarity standard deviation: {inter_global_avg_df[inter_global_avg_df['anno1'].isin(asynchronous_annotators)]['average_sim'].std():.2f}")
# Out:
# Synchronous global inter theme similarity average: 0.40
# Synchronous global inter theme similarity standard deviation: 0.04
# Asynchronous global inter theme similarity average: 0.40
# Asynchronous global inter theme similarity standard deviation: 0.04
